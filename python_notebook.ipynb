# %%
import requests
import time
import sys
from bs4 import BeautifulSoup
import json
 
cookies = {
    '_cq_duid': '1.1744778181.6MobFmGeC2R1nUU7',
    'split': 'n',
    '__vst': '510a7abc-5631-4c8b-a9a5-54de51e58a8a',
    '__bot': 'false',
    '_lr_env_src_ats': 'false',
    'permutive-id': '36491759-b0ef-4036-bc03-7d07f765413e',
    's_ecid': 'MCMID%7C62206642167978879802294781651943730817',
    '_cc_id': 'f15316d1891455e0cdcc7f071e6be91a',
    '_gcl_au': '1.1.761638148.1744778188',
    'pbjs-unifiedid': '%7B%22TDID%22%3A%22768f16ce-051a-44b9-986e-505d5a184422%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222025-03-16T04%3A36%3A27%22%7D',
    'pbjs-unifiedid_cst': 'VyxHLMwsHQ%3D%3D',
    '__gsas': 'ID=b761dbf92fed2797:T=1744778187:RT=1744778187:S=ALNI_MYyPr435-r92Lh6hgKWE7ir2wPpFg',
    '__split': '11',
    '_ga': 'GA1.1.122217795.1744778189',
    '_fbp': 'fb.1.1744778190942.615506763789365416',
    'ajs_anonymous_id': '484b625d-2e90-49a9-82ea-71509bf26df2',
    'kampyle_userid': '597b-3652-68fb-14df-8b6d-f4a2-9005-9eb6',
    'cto_bundle': 'OyMQ419RVHR2WTVsekpyUlYyaUt1RzBVN25kNWJ5eG45aU1kZ21lc3NIREpMTHVNcm4ybXA5Z0ZmMzF3YXZZaEVISyUyQlpoeE9rQlN3N2dsNVlWZmRwc2d6TjhucUExcSUyQjhwSHVqNExBVjdVZUU3eE5OdjRmRlc2SEZld3c2SFhpMVI0Slh0NmN6Ymh3MzlPN1kzJTJGeFZObEklMkJpQSUzRCUzRA',
    'G_ENABLED_IDPS': 'google',
    '__spdt': 'fec8a0e0243d44f7ac0a8810ea3a5617',
    '_pbjs_userid_consent_data': '3524755945110770',
    'spec-property-history': 'true',
    '_lr_sampling_rate': '100',
    'sbjs_migrations': '1418474375998%3D1',
    'sbjs_current_add': 'fd%3D2025-05-13%2015%3A38%3A57%7C%7C%7Cep%3Dhttps%3A%2F%2Fwww.realtor.com%2Frealestateagents%2FMarie-Crabb_San-Antonio_TX_1562457_770159571%7C%7C%7Crf%3D%28none%29',
    'sbjs_first_add': 'fd%3D2025-05-13%2015%3A38%3A57%7C%7C%7Cep%3Dhttps%3A%2F%2Fwww.realtor.com%2Frealestateagents%2FMarie-Crabb_San-Antonio_TX_1562457_770159571%7C%7C%7Crf%3D%28none%29',
    'sbjs_current': 'typ%3Dtypein%7C%7C%7Csrc%3D%28direct%29%7C%7C%7Cmdm%3D%28none%29%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29',
    'sbjs_first': 'typ%3Dtypein%7C%7C%7Csrc%3D%28direct%29%7C%7C%7Cmdm%3D%28none%29%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29',
    'sbjs_udata': 'vst%3D1%7C%7C%7Cuip%3D%28none%29%7C%7C%7Cuag%3DMozilla%2F5.0%20%28Windows%20NT%2010.0%3B%20Win64%3B%20x64%29%20AppleWebKit%2F537.36%20%28KHTML%2C%20like%20Gecko%29%20Chrome%2F136.0.0.0%20Safari%2F537.36',
    'AWSALBTG': 'Gysy51HA+pJTrxIKFj2v3w0nCE/eoaQmJ7DSPj4suoUKY1CHB4l5GhwD4Qau/EW7RngdZBfgTbUsgutlOm0f96YiXJTcsrWR+T8lWoqugNfMSDTEbOwrgbTJv4zI4vgeWeD4ltJdQFCOglNyh0FuxME92j87R8+5+nrtZTwzAFAL',
    'AWSALBTGCORS': 'Gysy51HA+pJTrxIKFj2v3w0nCE/eoaQmJ7DSPj4suoUKY1CHB4l5GhwD4Qau/EW7RngdZBfgTbUsgutlOm0f96YiXJTcsrWR+T8lWoqugNfMSDTEbOwrgbTJv4zI4vgeWeD4ltJdQFCOglNyh0FuxME92j87R8+5+nrtZTwzAFAL',
    'AWSALB': 'PA4KsCC+ZE35rkHrZlFJmvdEFqqcwpfhPvIHyR8fvTkTuV8elUxXm3ZXx+OJ8h1qNL5Hsxp9M9bcRnTPQfhDhKnSOIaGtgnBBIXsSuTsBL6E4DClOUhJXGkw1ucY',
    'AWSALBCORS': 'PA4KsCC+ZE35rkHrZlFJmvdEFqqcwpfhPvIHyR8fvTkTuV8elUxXm3ZXx+OJ8h1qNL5Hsxp9M9bcRnTPQfhDhKnSOIaGtgnBBIXsSuTsBL6E4DClOUhJXGkw1ucY',
    'leadid_token-27789EFE-7A9A-DB70-BB9B-97D9B7057DBB-01836014-7527-FD48-9B7F-1A40A9705CFE': '86378343-6E72-C9A3-F38C-4FC85D4B9DDF',
    '_parsely_session': '{%22sid%22:25%2C%22surl%22:%22https://www.realtor.com/realestateandhomes-detail/127-Concord-St_Brooklyn_NY_11201_M94228-18638%22%2C%22sref%22:%22https://colab.research.google.com/%22%2C%22sts%22:1747135330658%2C%22slts%22:1747130960659}',
    '_parsely_visitor': '{%22id%22:%22pid=1b405088-93a3-4244-a70a-8f0b5d157233%22%2C%22session_count%22:25%2C%22last_session_ts%22:1747135330658}',
    '_lr_retry_request': 'true',
    'AMP_MKTG_c07a79acf5': 'JTdCJTdE',
    'claritas_24hrexp_ldp': 'true',
    'split_tcv': '123',
    'panoramaId_expiry': '1747223247759',
    'panoramaId': '1c8ce1f32d9b77f43d98a20754f4a9fb927a4d1c3ceb4de2702245f6f0c8d4e0',
    'ab.storage.deviceId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3Ac0e51af7-dd43-dbd5-e0cf-a1fa33760e57%7Ce%3Aundefined%7Cc%3A1744778189271%7Cl%3A1747136849038',
    'ab.storage.userId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3Avisitor_510a7abc-5631-4c8b-a9a5-54de51e58a8a%7Ce%3Aundefined%7Cc%3A1744778189264%7Cl%3A1747136849040',
    'kampyleUserSession': '1747136968797',
    'kampyleUserSessionsCount': '73',
    'kampyleSessionPageCounter': '1',
    'kampyleUserPercentile': '38.99125802441098',
    '__ssn': '12d7e70c-46a9-45b7-8708-9b6155f748af',
    '__ssnstarttime': '1747138479',
    'criteria': 'sprefix%3D%252Fnewhomecommunities%26area_type%3Dcity%26city%3DNew%2520York%26pg%3D1%26state_code%3DNY%26state_id%3DNY%26loc%3DNew%2520York%252C%2520NY%26locSlug%3DNew-York_NY%26county_fips%3D36081%26county_fips_multi%3D36081-36047-36085-36005-36061',
    'isAuth0GnavEnabled': 'C',
    'AMCVS_8853394255142B6A0A4C98A4%40AdobeOrg': '1',
    'AMCV_8853394255142B6A0A4C98A4%40AdobeOrg': '-1124106680%7CMCIDTS%7C20221%7CMCMID%7C62206642167978879802294781651943730817%7CMCAAMLH-1747743283%7C12%7CMCAAMB-1747743283%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1747145683s%7CNONE%7CMCAID%7CNONE%7CvVersion%7C5.2.0',
    'claritas_24hrexp_sitevisit': 'true',
    'ab.storage.sessionId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3A5e73a82d-0856-363b-ebe3-ab7bcf82f658%7Ce%3A1747140285057%7Cc%3A1747136849034%7Cl%3A1747138485057',
    '_uetsid': '523b07802f1e11f0a6117f38eb0c06f4|nu1ncn|2|fvv|0|1958',
    'AMP_c07a79acf5': '',
    '__gads': 'ID=90cc70a1b7f62534:T=1744778191:RT=1747138485:S=ALNI_Mbwq8lNnQn41vMslb5NKa0v1IXODQ',
    '__gpi': 'UID=000010a0d44ff64d:T=1744778191:RT=1747138485:S=ALNI_MYQOz2G493eHyeT1BxhNY1pSbZ_ZQ',
    '__eoi': 'ID=ff471cc055362e70:T=1744778191:RT=1747138485:S=AA-AfjY5Nukxc6S-HKQMxCxsgauf',
    '_uetvid': '5e6611101a7c11f096fd0b3e24a7f2ce|1glbpa|1747138486190|3|1|bat.bing.com/p/insights/c/b',
    '_ga_07XBH6XBNS': 'GS2.1.s1747135361$o25$g0$t1747138488$j0$l0$h538070340',
    '_ga_MS5EHT6J6V': 'GS2.1.s1747135361$o25$g1$t1747138488$j0$l0$h0',
    'KP_UIDz-ssn': '0MfNNCrrSb9BV7sBp4WHRRcf76Hju6CLGwabGOT0OemzWxp7pYt891SoHjCmiqzeE4EogTl5pik6AxlNeZssOqeTyXwkGLi6ak34mTbRw8IRL3eAxozFBk7kKCJKW4DrGUsqoPvVO0Mi9LFWIIbEhrxyequ0ffzwIJVbhdPx',
    'KP_UIDz': '0MfNNCrrSb9BV7sBp4WHRRcf76Hju6CLGwabGOT0OemzWxp7pYt891SoHjCmiqzeE4EogTl5pik6AxlNeZssOqeTyXwkGLi6ak34mTbRw8IRL3eAxozFBk7kKCJKW4DrGUsqoPvVO0Mi9LFWIIbEhrxyequ0ffzwIJVbhdPx',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
    # 'cookie': '_cq_duid=1.1744778181.6MobFmGeC2R1nUU7; split=n; __vst=510a7abc-5631-4c8b-a9a5-54de51e58a8a; __bot=false; _lr_env_src_ats=false; permutive-id=36491759-b0ef-4036-bc03-7d07f765413e; s_ecid=MCMID%7C62206642167978879802294781651943730817; _cc_id=f15316d1891455e0cdcc7f071e6be91a; _gcl_au=1.1.761638148.1744778188; pbjs-unifiedid=%7B%22TDID%22%3A%22768f16ce-051a-44b9-986e-505d5a184422%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222025-03-16T04%3A36%3A27%22%7D; pbjs-unifiedid_cst=VyxHLMwsHQ%3D%3D; __gsas=ID=b761dbf92fed2797:T=1744778187:RT=1744778187:S=ALNI_MYyPr435-r92Lh6hgKWE7ir2wPpFg; __split=11; _ga=GA1.1.122217795.1744778189; _fbp=fb.1.1744778190942.615506763789365416; ajs_anonymous_id=484b625d-2e90-49a9-82ea-71509bf26df2; kampyle_userid=597b-3652-68fb-14df-8b6d-f4a2-9005-9eb6; cto_bundle=OyMQ419RVHR2WTVsekpyUlYyaUt1RzBVN25kNWJ5eG45aU1kZ21lc3NIREpMTHVNcm4ybXA5Z0ZmMzF3YXZZaEVISyUyQlpoeE9rQlN3N2dsNVlWZmRwc2d6TjhucUExcSUyQjhwSHVqNExBVjdVZUU3eE5OdjRmRlc2SEZld3c2SFhpMVI0Slh0NmN6Ymh3MzlPN1kzJTJGeFZObEklMkJpQSUzRCUzRA; G_ENABLED_IDPS=google; __spdt=fec8a0e0243d44f7ac0a8810ea3a5617; _pbjs_userid_consent_data=3524755945110770; spec-property-history=true; _lr_sampling_rate=100; sbjs_migrations=1418474375998%3D1; sbjs_current_add=fd%3D2025-05-13%2015%3A38%3A57%7C%7C%7Cep%3Dhttps%3A%2F%2Fwww.realtor.com%2Frealestateagents%2FMarie-Crabb_San-Antonio_TX_1562457_770159571%7C%7C%7Crf%3D%28none%29; sbjs_first_add=fd%3D2025-05-13%2015%3A38%3A57%7C%7C%7Cep%3Dhttps%3A%2F%2Fwww.realtor.com%2Frealestateagents%2FMarie-Crabb_San-Antonio_TX_1562457_770159571%7C%7C%7Crf%3D%28none%29; sbjs_current=typ%3Dtypein%7C%7C%7Csrc%3D%28direct%29%7C%7C%7Cmdm%3D%28none%29%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29; sbjs_first=typ%3Dtypein%7C%7C%7Csrc%3D%28direct%29%7C%7C%7Cmdm%3D%28none%29%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29; sbjs_udata=vst%3D1%7C%7C%7Cuip%3D%28none%29%7C%7C%7Cuag%3DMozilla%2F5.0%20%28Windows%20NT%2010.0%3B%20Win64%3B%20x64%29%20AppleWebKit%2F537.36%20%28KHTML%2C%20like%20Gecko%29%20Chrome%2F136.0.0.0%20Safari%2F537.36; AWSALBTG=Gysy51HA+pJTrxIKFj2v3w0nCE/eoaQmJ7DSPj4suoUKY1CHB4l5GhwD4Qau/EW7RngdZBfgTbUsgutlOm0f96YiXJTcsrWR+T8lWoqugNfMSDTEbOwrgbTJv4zI4vgeWeD4ltJdQFCOglNyh0FuxME92j87R8+5+nrtZTwzAFAL; AWSALBTGCORS=Gysy51HA+pJTrxIKFj2v3w0nCE/eoaQmJ7DSPj4suoUKY1CHB4l5GhwD4Qau/EW7RngdZBfgTbUsgutlOm0f96YiXJTcsrWR+T8lWoqugNfMSDTEbOwrgbTJv4zI4vgeWeD4ltJdQFCOglNyh0FuxME92j87R8+5+nrtZTwzAFAL; AWSALB=PA4KsCC+ZE35rkHrZlFJmvdEFqqcwpfhPvIHyR8fvTkTuV8elUxXm3ZXx+OJ8h1qNL5Hsxp9M9bcRnTPQfhDhKnSOIaGtgnBBIXsSuTsBL6E4DClOUhJXGkw1ucY; AWSALBCORS=PA4KsCC+ZE35rkHrZlFJmvdEFqqcwpfhPvIHyR8fvTkTuV8elUxXm3ZXx+OJ8h1qNL5Hsxp9M9bcRnTPQfhDhKnSOIaGtgnBBIXsSuTsBL6E4DClOUhJXGkw1ucY; leadid_token-27789EFE-7A9A-DB70-BB9B-97D9B7057DBB-01836014-7527-FD48-9B7F-1A40A9705CFE=86378343-6E72-C9A3-F38C-4FC85D4B9DDF; _parsely_session={%22sid%22:25%2C%22surl%22:%22https://www.realtor.com/realestateandhomes-detail/127-Concord-St_Brooklyn_NY_11201_M94228-18638%22%2C%22sref%22:%22https://colab.research.google.com/%22%2C%22sts%22:1747135330658%2C%22slts%22:1747130960659}; _parsely_visitor={%22id%22:%22pid=1b405088-93a3-4244-a70a-8f0b5d157233%22%2C%22session_count%22:25%2C%22last_session_ts%22:1747135330658}; _lr_retry_request=true; AMP_MKTG_c07a79acf5=JTdCJTdE; claritas_24hrexp_ldp=true; split_tcv=123; panoramaId_expiry=1747223247759; panoramaId=1c8ce1f32d9b77f43d98a20754f4a9fb927a4d1c3ceb4de2702245f6f0c8d4e0; ab.storage.deviceId.7cc9d032-9d6d-44cf-a8f5-d276489af322=g%3Ac0e51af7-dd43-dbd5-e0cf-a1fa33760e57%7Ce%3Aundefined%7Cc%3A1744778189271%7Cl%3A1747136849038; ab.storage.userId.7cc9d032-9d6d-44cf-a8f5-d276489af322=g%3Avisitor_510a7abc-5631-4c8b-a9a5-54de51e58a8a%7Ce%3Aundefined%7Cc%3A1744778189264%7Cl%3A1747136849040; kampyleUserSession=1747136968797; kampyleUserSessionsCount=73; kampyleSessionPageCounter=1; kampyleUserPercentile=38.99125802441098; __ssn=12d7e70c-46a9-45b7-8708-9b6155f748af; __ssnstarttime=1747138479; criteria=sprefix%3D%252Fnewhomecommunities%26area_type%3Dcity%26city%3DNew%2520York%26pg%3D1%26state_code%3DNY%26state_id%3DNY%26loc%3DNew%2520York%252C%2520NY%26locSlug%3DNew-York_NY%26county_fips%3D36081%26county_fips_multi%3D36081-36047-36085-36005-36061; isAuth0GnavEnabled=C; AMCVS_8853394255142B6A0A4C98A4%40AdobeOrg=1; AMCV_8853394255142B6A0A4C98A4%40AdobeOrg=-1124106680%7CMCIDTS%7C20221%7CMCMID%7C62206642167978879802294781651943730817%7CMCAAMLH-1747743283%7C12%7CMCAAMB-1747743283%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1747145683s%7CNONE%7CMCAID%7CNONE%7CvVersion%7C5.2.0; claritas_24hrexp_sitevisit=true; ab.storage.sessionId.7cc9d032-9d6d-44cf-a8f5-d276489af322=g%3A5e73a82d-0856-363b-ebe3-ab7bcf82f658%7Ce%3A1747140285057%7Cc%3A1747136849034%7Cl%3A1747138485057; _uetsid=523b07802f1e11f0a6117f38eb0c06f4|nu1ncn|2|fvv|0|1958; AMP_c07a79acf5=; __gads=ID=90cc70a1b7f62534:T=1744778191:RT=1747138485:S=ALNI_Mbwq8lNnQn41vMslb5NKa0v1IXODQ; __gpi=UID=000010a0d44ff64d:T=1744778191:RT=1747138485:S=ALNI_MYQOz2G493eHyeT1BxhNY1pSbZ_ZQ; __eoi=ID=ff471cc055362e70:T=1744778191:RT=1747138485:S=AA-AfjY5Nukxc6S-HKQMxCxsgauf; _uetvid=5e6611101a7c11f096fd0b3e24a7f2ce|1glbpa|1747138486190|3|1|bat.bing.com/p/insights/c/b; _ga_07XBH6XBNS=GS2.1.s1747135361$o25$g0$t1747138488$j0$l0$h538070340; _ga_MS5EHT6J6V=GS2.1.s1747135361$o25$g1$t1747138488$j0$l0$h0; KP_UIDz-ssn=0MfNNCrrSb9BV7sBp4WHRRcf76Hju6CLGwabGOT0OemzWxp7pYt891SoHjCmiqzeE4EogTl5pik6AxlNeZssOqeTyXwkGLi6ak34mTbRw8IRL3eAxozFBk7kKCJKW4DrGUsqoPvVO0Mi9LFWIIbEhrxyequ0ffzwIJVbhdPx; KP_UIDz=0MfNNCrrSb9BV7sBp4WHRRcf76Hju6CLGwabGOT0OemzWxp7pYt891SoHjCmiqzeE4EogTl5pik6AxlNeZssOqeTyXwkGLi6ak34mTbRw8IRL3eAxozFBk7kKCJKW4DrGUsqoPvVO0Mi9LFWIIbEhrxyequ0ffzwIJVbhdPx',
}
 

location=location
# days=days
# price=price
# property_type="property_type"
final_url=final_url

url = f"https://www.realtor.com/realestateandhomes-search/{location}"

if final_url:
   url+=final_url

# if days:
#     url += f"/dom-{int(days)}"
# if price:
#     url += f"/price-{int(price)}-na"
# if property_type:
#     url += f"/type-{property_type.replace(' ', '-').lower()}"

print("🔗 Final URL:", url)
print("final url is ", final_url)

response = requests.get(
    # 'https://www.realtor.com/realestateandhomes-search/Indiana/type-multi-family-home/dom-30/price-800000-na',
    url,
    cookies=cookies,
    headers=headers,
)


link_array=[]

soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())
# total_homes=soup.find('div', class_="TotalResults_totalNumber__ejYIx")
total_homes = soup.find('div', attrs={'data-testid': 'total-results'})
# script_tag = soup.find('script', {'data-testid': 'seoLinkingData', 'type': 'application/ld+json'})
script_tag = soup.find('script', {'id': '__NEXT_DATA__', 'type': 'application/json'})
# print(script_tag)
# print(total_homes.text)


def get_main_entity_item_list(json_data):
    for item in json_data:
        if "mainEntity" in item:
            main_entity = item["mainEntity"]
            if "itemListElement" in main_entity:
                return main_entity["itemListElement"]
    return None  # Return None if not found

if script_tag:
  # Load the content of the script tag (it's a JSON string)
  json_data = json.loads(script_tag.string)
  # print(json_data)
  # print(json.dumps(json_data, indent=2))
  new_data=json_data["props"]["pageProps"]["properties"]
  # print(json.dumps(new_data, indent=2))
  permalinks = [item.get("permalink") for item in new_data]

print(permalinks)
link_array.append(permalinks)
# print(len(permalinks))
  # ans=json_data[1]["mainEntity"]["itemListElement"]
  # ans=get_main_entity_item_list(json_data)

  # print(json.dumps(ans,indent=2))
  # print(ans)
  # c=0
  # if (ans):
  #   for i in ans:
  #     # print(i["url"])
  #     link_array.append(i["url"])
  #     c=c+1
#   print(c)

print(total_homes.text.strip())
# Out:
# 198

# %%
import math
 

if total_homes:  # Add your condition here (e.g., ensure the element exists)
    total_homes_number = int(total_homes.text.strip().replace(',', ''))

    # Now do the math
    page = math.ceil(total_homes_number / len(permalinks) )
    print("heyyyyyyyy" ,page)

    for p in range(2, page + 1):
        response = requests.get(
            f'{url}/pg-{p}',
            cookies=cookies,
            headers=headers,
        )
        print("mmmmmmmmmmmmmmmmmmmm", f'{url}/pg-{p}')
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            script_tag = soup.find('script', {'id': '__NEXT_DATA__', 'type': 'application/json'})
            # script_tag = soup.find('script', {'data-testid': 'seoLinkingData', 'type': 'application/ld+json'})

            

            if script_tag:
                try:
                    # Load the content of the script tag (it's a JSON string)
                    json_data = json.loads(script_tag.string)
                     
                    new_data=json_data["props"]["pageProps"]["properties"]
                    # print(json.dumps(new_data, indent=2))
                    permalinks = [item.get("permalink") for item in new_data]
                    link_array.append(permalinks)

                    # c = 0
                    # if ans:
                    #     for i in ans:
                    #         print(i["url"])
                    #         link_array.append(i["url"])
                    #         c += 1
                    print("\n\n\n\n", p)
                except Exception as e:
                    print(f"Error parsing page {p}: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       1 import math
#       2 # total_homes_number = int(total_homes.text.strip())
#       3 # page = math.ceil(total_homes_number / 40)
#       4
#       5 # for 7,788 then i am using below code
#       6 # Remove commas before converting to int
# ----> 7 total_homes_number = int(total_homes.text.strip().replace(',', ''))
#       9 # Now do the math
#      10 page = math.ceil(total_homes_number / 40)
#
# NameError: name 'total_homes' is not defined

# %%
flat_links = [link for sublist in link_array for link in sublist]
flat_links
# Out:
# 198

# %%
import requests
 

cookies = {
    'split': 'n',
    'split_tcv': '193',
    '__ssn': '0c59f910-ec83-4a58-8952-79d151a7552a',
    '__ssnstarttime': '1757563321',
    'KP_UIDz-ssn': '0bt8S0dy2kvh1aWrYXQ0FVmbVVFJ331AzjDke8tZm0l1fqJTp9MP3A4kAeZNOy8aEaKdVmjXPiHQAJqOo4meZbKjnimiwRIkpCqvfXWNq7AYlzA4OzaMiL9Q8N3wsE6PvF2eBHQUovqnO9bMIaxYRqGgLNwyDl6hVrUKv0Rg6WPTp2V',
    'KP_UIDz': '0bt8S0dy2kvh1aWrYXQ0FVmbVVFJ331AzjDke8tZm0l1fqJTp9MP3A4kAeZNOy8aEaKdVmjXPiHQAJqOo4meZbKjnimiwRIkpCqvfXWNq7AYlzA4OzaMiL9Q8N3wsE6PvF2eBHQUovqnO9bMIaxYRqGgLNwyDl6hVrUKv0Rg6WPTp2V',
    '__vst': 'b2ac4700-f4d6-4f15-afa9-68e35514ef55',
    '__bot': 'false',
    '__split': '16',
    '__rdc_id': 'rdc-id-e54b7cd7-d909-412d-9019-ffeb79959c84',
    '_lr_retry_request': 'true',
    '_lr_env_src_ats': 'false',
    'AMCVS_8853394255142B6A0A4C98A4%40AdobeOrg': '1',
    's_ecid': 'MCMID%7C36374151266383763803798383151001480396',
    'ab.storage.userId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3Avisitor_b2ac4700-f4d6-4f15-afa9-68e35514ef55%7Ce%3Aundefined%7Cc%3A1757563322768%7Cl%3A1757563322771',
    'ab.storage.deviceId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3Aabdd740a-7ba0-5365-99d2-5c93befa00b9%7Ce%3Aundefined%7Cc%3A1757563322772%7Cl%3A1757563322772',
    'ab.storage.sessionId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3Ac0a92f69-69e0-0997-cc75-6aca62d71f8e%7Ce%3A1757565122778%7Cc%3A1757563322770%7Cl%3A1757563322778',
    'permutive-id': 'd505120e-1538-4b36-8386-a014b6ddde23',
    'AMCV_8853394255142B6A0A4C98A4%40AdobeOrg': '-1124106680%7CMCIDTS%7C20343%7CMCMID%7C36374151266383763803798383151001480396%7CMCAAMLH-1758168122%7C12%7CMCAAMB-1758168122%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1757570523s%7CNONE%7CMCAID%7CNONE%7CvVersion%7C5.2.0',
    '_gcl_au': '1.1.1208071516.1757563323',
    '_fbp': 'fb.1.1757563323571.3385013820',
    'claritas_24hrexp_ldp': 'true',
    'pbjs-unifiedid': '%7B%22TDID%22%3A%2204797ec6-ee15-45b9-b561-d83efd60b0ea%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222025-08-11T04%3A02%3A03%22%7D',
    'pbjs-unifiedid_cst': 'VyxHLMwsHQ%3D%3D',
    'panoramaId_expiry': '1758168124070',
    '_cc_id': '21130b7ea1d750ddaa9ea02470ec607e',
    'panoramaId': 'eff40b94738d0a3708a0d3954ec84945a702961d05d1784f4a560cd5ff0ccd12',
    '__spdt': 'de0b2d4babd5498997eaee94fde713e1',
    '_ga': 'GA1.1.626864144.1757563325',
    'G_ENABLED_IDPS': 'google',
    'ajs_anonymous_id': '040250b0-bc7d-4f04-9fd7-df792f56223b',
    '_uetsid': '15013e808ec411f0b4f4c14d36f56472|1rl08hl|2|fz8|0|2080',
    '_lr_sampling_rate': '100',
    '_awl': '2.1757563334.5-2de8c429cc2dba075db6e00aa625ef51-6763652d617369612d6561737431-0',
    '_uetvid': '1501e8b08ec411f0b05163b8e2198b44|162wdaw|1757563335199|1|1|bat.bing.com/p/insights/c/f',
    'AMP_MKTG_c07a79acf5': 'JTdCJTdE',
    'AMP_c07a79acf5': '',
    '_ga_07XBH6XBNS': 'GS2.1.s1757563324$o1$g0$t1757563339$j45$l0$h1251619243',
    '_ga_MS5EHT6J6V': 'GS2.1.s1757563325$o1$g0$t1757563339$j46$l0$h0',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9,hi;q=0.8',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'referer': 'https://www.realtor.com/realestateandhomes-detail/3078-E-6th-St_Los-Angeles_CA_90023_M28581-73475?from=srp-list-card',
    'sec-ch-ua': '"Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36',
    # 'cookie': 'split=n; split_tcv=193; __ssn=0c59f910-ec83-4a58-8952-79d151a7552a; __ssnstarttime=1757563321; KP_UIDz-ssn=0bt8S0dy2kvh1aWrYXQ0FVmbVVFJ331AzjDke8tZm0l1fqJTp9MP3A4kAeZNOy8aEaKdVmjXPiHQAJqOo4meZbKjnimiwRIkpCqvfXWNq7AYlzA4OzaMiL9Q8N3wsE6PvF2eBHQUovqnO9bMIaxYRqGgLNwyDl6hVrUKv0Rg6WPTp2V; KP_UIDz=0bt8S0dy2kvh1aWrYXQ0FVmbVVFJ331AzjDke8tZm0l1fqJTp9MP3A4kAeZNOy8aEaKdVmjXPiHQAJqOo4meZbKjnimiwRIkpCqvfXWNq7AYlzA4OzaMiL9Q8N3wsE6PvF2eBHQUovqnO9bMIaxYRqGgLNwyDl6hVrUKv0Rg6WPTp2V; __vst=b2ac4700-f4d6-4f15-afa9-68e35514ef55; __bot=false; __split=16; __rdc_id=rdc-id-e54b7cd7-d909-412d-9019-ffeb79959c84; _lr_retry_request=true; _lr_env_src_ats=false; AMCVS_8853394255142B6A0A4C98A4%40AdobeOrg=1; s_ecid=MCMID%7C36374151266383763803798383151001480396; ab.storage.userId.7cc9d032-9d6d-44cf-a8f5-d276489af322=g%3Avisitor_b2ac4700-f4d6-4f15-afa9-68e35514ef55%7Ce%3Aundefined%7Cc%3A1757563322768%7Cl%3A1757563322771; ab.storage.deviceId.7cc9d032-9d6d-44cf-a8f5-d276489af322=g%3Aabdd740a-7ba0-5365-99d2-5c93befa00b9%7Ce%3Aundefined%7Cc%3A1757563322772%7Cl%3A1757563322772; ab.storage.sessionId.7cc9d032-9d6d-44cf-a8f5-d276489af322=g%3Ac0a92f69-69e0-0997-cc75-6aca62d71f8e%7Ce%3A1757565122778%7Cc%3A1757563322770%7Cl%3A1757563322778; permutive-id=d505120e-1538-4b36-8386-a014b6ddde23; AMCV_8853394255142B6A0A4C98A4%40AdobeOrg=-1124106680%7CMCIDTS%7C20343%7CMCMID%7C36374151266383763803798383151001480396%7CMCAAMLH-1758168122%7C12%7CMCAAMB-1758168122%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1757570523s%7CNONE%7CMCAID%7CNONE%7CvVersion%7C5.2.0; _gcl_au=1.1.1208071516.1757563323; _fbp=fb.1.1757563323571.3385013820; claritas_24hrexp_ldp=true; pbjs-unifiedid=%7B%22TDID%22%3A%2204797ec6-ee15-45b9-b561-d83efd60b0ea%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222025-08-11T04%3A02%3A03%22%7D; pbjs-unifiedid_cst=VyxHLMwsHQ%3D%3D; panoramaId_expiry=1758168124070; _cc_id=21130b7ea1d750ddaa9ea02470ec607e; panoramaId=eff40b94738d0a3708a0d3954ec84945a702961d05d1784f4a560cd5ff0ccd12; __spdt=de0b2d4babd5498997eaee94fde713e1; _ga=GA1.1.626864144.1757563325; G_ENABLED_IDPS=google; ajs_anonymous_id=040250b0-bc7d-4f04-9fd7-df792f56223b; _uetsid=15013e808ec411f0b4f4c14d36f56472|1rl08hl|2|fz8|0|2080; _lr_sampling_rate=100; _awl=2.1757563334.5-2de8c429cc2dba075db6e00aa625ef51-6763652d617369612d6561737431-0; _uetvid=1501e8b08ec411f0b05163b8e2198b44|162wdaw|1757563335199|1|1|bat.bing.com/p/insights/c/f; AMP_MKTG_c07a79acf5=JTdCJTdE; AMP_c07a79acf5=; _ga_07XBH6XBNS=GS2.1.s1757563324$o1$g0$t1757563339$j45$l0$h1251619243; _ga_MS5EHT6J6V=GS2.1.s1757563325$o1$g0$t1757563339$j46$l0$h0',
}

params = {
    'from': 'srp-list-card',
}

# response = requests.get(
#     'https://www.realtor.com/realestateandhomes-detail/3078-E-6th-St_Los-Angeles_CA_90023_M28581-73475',
#     params=params,
#     cookies=cookies,
#     headers=headers,
# )

# %%
from ast import main
import requests
from bs4 import BeautifulSoup
import json
import time
import re
result=[]

 
k=1
 

if link_array:  # Add your condition here (e.g., len(link_array) > 0)
    for link in flat_links:
        # link=link+'?from=srp-list-card'
        link="https://www.realtor.com/realestateandhomes-detail/"+link
        print(link)
        detail_res = requests.get(link, params=params, cookies=cookies, headers=headers)
        k = k + 1
        print(detail_res, k)
        data = {
            "Price": "N/A",
            "Address": "N/A",
            "Realtor's Name": "N/A",
            "Realtor's Email": "N/A",
            "Realtor's Phone": "N/A",
            "Brokered Name": "N/A",
            "Estimated Price": "N/A",
            "Property Type": "N/A",
            "Days on Market": "N/A",
            "Year Built": "N/A",
            "Zip Code": "N/A",
            "Multi Listings": "N/A",
            "Link": link,
        }

        if detail_res.status_code == 200:
            # time.sleep(3)  # delay to avoid blocking
            detail_soup = BeautifulSoup(detail_res.text, 'html.parser')

            main_price = detail_soup.find("span", class_="base__StyledType-rui__sc-18muj27-0 idlIli")
            
            if main_price:
                data['Price'] = main_price.text.strip()

            main_address = detail_soup.find("h1", class_="sc-fa97e35a-3 dgxOov")
            
            if main_address:
                data['Address'] = main_address.text.strip()

            script_tag = detail_soup.find('script', {'id': '__NEXT_DATA__', 'type': 'application/json'})
            if script_tag:
                try:
                    json_data = json.loads(script_tag.string)
                    advertiser_info = json_data["props"]["pageProps"]["initialReduxState"]["propertyDetails"]["advertisers"][0]

                    data["Realtor's Name"] = advertiser_info.get("name", "N/A")
                    data["Realtor's Email"] = advertiser_info.get("email", "N/A")
                    data["Realtor's Phone"] = advertiser_info["phones"][0].get("number", "N/A")
                    data["Brokered Name"] = advertiser_info["office"].get("name")
                    data["Estimated Price"] = json_data["props"]["pageProps"]["initialReduxState"]["propertyDetails"].get("estimate", {}).get("price", "N/A")
                    data["Zip Code"] = re.search(r'\b\d{5}\b', detail_soup.text).group() if re.search(r'\b\d{5}\b', detail_soup.text) else "N/A"
                except Exception as e:
                    data["error"] = str(e)

            # multi_listings = detail_soup.find("div", class_="sc-205c724c-0 ficrCd")
            # if multi_listings:
            #     listings = multi_listings.find_all('a')
            #     data["Multi Listings"] = len(listings)

            multi_listings = detail_soup.find("div", class_="sc-205c724c-0 ficrCd")
            if multi_listings:
                listings = multi_listings.find_all('a')
                data["Multi Listings"] = str(len(listings))   
            else:
                data["Multi Listings"] = "0"   

 

            fifi = detail_soup.find("ul", "sc-596aad4c-0 fdDkrT")
            if fifi:
                prop_type_tag = fifi.find('span', string="Property type")
                data["Property Type"] = prop_type_tag.find_next('p').text.strip() if prop_type_tag else "N/A"

                # dom_tag = fifi.find('span', string="On Realtor.com")
                # data["Days on Market"] = dom_tag.find_next('p').text.strip() if dom_tag else "N/A"
                dom_tag = fifi.find('p', class_="base__StyledType-rui__sc-18muj27-0 bNJOGz sc-c1d03842-3 cCvGvj")
                data["Days on Market"] = dom_tag.find_next('p').text.strip() if dom_tag else "N/A"

                year_built_tag = fifi.find('span', string="Year built")
                data["Year Built"] = year_built_tag.find_next('p').text.strip() if year_built_tag else "N/A"

            estim = detail_soup.find("div", "mortgage-components-bx9k35 jhJBqN")
            if estim:
                price = estim.find('span', class_='base__StyledType-rui__sc-18muj27-0 idlIli')
                
                if price:
                    data["Estimated Price"] = price.text.strip()

        result.append(data)

else:
    result.append({'message': 'No property URLs found.'})
# Out:
# <Response [200]> 2
# <Response [200]> 3
# <Response [200]> 4
# <Response [200]> 5
# <Response [200]> 6
# <Response [200]> 7
# <Response [200]> 8
# <Response [200]> 9
# <Response [200]> 10
# <Response [200]> 11
# <Response [200]> 12
# <Response [200]> 13
# <Response [200]> 14
# <Response [200]> 15
# <Response [200]> 16
# <Response [200]> 17
# <Response [200]> 18
# <Response [200]> 19
# <Response [200]> 20
# <Response [200]> 21
# <Response [200]> 22
# <Response [200]> 23
# <Response [200]> 24
# <Response [200]> 25
# <Response [200]> 26
# <Response [200]> 27
# <Response [200]> 28
# <Response [200]> 29
# <Response [200]> 30
# <Response [200]> 31
# <Response [200]> 32
# <Response [200]> 33
# <Response [200]> 34
# <Response [200]> 35
# <Response [200]> 36
# <Response [200]> 37
# <Response [200]> 38
# <Response [200]> 39
# <Response [200]> 40
# <Response [200]> 41
# <Response [200]> 42
# <Response [200]> 43
# <Response [200]> 44
# <Response [200]> 45
# <Response [200]> 46
# <Response [200]> 47
# <Response [200]> 48
# <Response [200]> 49
# <Response [200]> 50
# <Response [200]> 51
# <Response [200]> 52
# <Response [200]> 53
# <Response [200]> 54
# <Response [200]> 55
# <Response [200]> 56
# <Response [200]> 57
# <Response [200]> 58
# <Response [200]> 59
# <Response [200]> 60
# <Response [200]> 61
# <Response [200]> 62
# <Response [200]> 63
# <Response [200]> 64
# <Response [200]> 65
# <Response [200]> 66
# <Response [200]> 67
# <Response [200]> 68
# <Response [200]> 69
# <Response [200]> 70
# <Response [200]> 71
# <Response [200]> 72
# <Response [200]> 73
# <Response [200]> 74
# <Response [200]> 75
# <Response [200]> 76
# <Response [200]> 77
# <Response [200]> 78
# <Response [200]> 79
# <Response [200]> 80
# <Response [200]> 81
# <Response [200]> 82
# <Response [200]> 83
# <Response [200]> 84
# <Response [200]> 85
# <Response [200]> 86
# <Response [200]> 87
# <Response [200]> 88
# <Response [200]> 89
# <Response [200]> 90
# <Response [200]> 91
# <Response [200]> 92
# <Response [200]> 93
# <Response [200]> 94
# <Response [200]> 95
# <Response [200]> 96
# <Response [200]> 97
# <Response [200]> 98
# <Response [200]> 99
# <Response [200]> 100
# <Response [200]> 101
# <Response [200]> 102
# <Response [200]> 103
# <Response [200]> 104
# <Response [200]> 105
# <Response [200]> 106
# <Response [200]> 107
# <Response [200]> 108
# <Response [200]> 109
# <Response [200]> 110
# <Response [200]> 111
# <Response [200]> 112
# <Response [200]> 113
# <Response [200]> 114
# <Response [200]> 115
# <Response [200]> 116
# <Response [200]> 117
# <Response [200]> 118
# <Response [200]> 119
# <Response [200]> 120
# <Response [200]> 121
# <Response [200]> 122
# <Response [200]> 123
# <Response [200]> 124
# <Response [200]> 125
# <Response [200]> 126
# <Response [200]> 127
# <Response [200]> 128
# <Response [200]> 129
# <Response [200]> 130
# <Response [200]> 131
# <Response [200]> 132
# <Response [200]> 133
# <Response [200]> 134
# <Response [200]> 135
# <Response [200]> 136
# <Response [200]> 137
# <Response [200]> 138
# <Response [200]> 139
# <Response [200]> 140
# <Response [200]> 141
# <Response [200]> 142
# <Response [200]> 143
# <Response [200]> 144
# <Response [200]> 145
# <Response [200]> 146
# <Response [200]> 147
# <Response [200]> 148
# <Response [200]> 149
# <Response [200]> 150
# <Response [200]> 151
# <Response [200]> 152
# <Response [200]> 153
# <Response [200]> 154
# <Response [200]> 155
# <Response [200]> 156
# <Response [200]> 157
# <Response [200]> 158
# <Response [200]> 159
# <Response [200]> 160
# <Response [200]> 161
# <Response [200]> 162
# <Response [200]> 163
# <Response [200]> 164
# <Response [200]> 165
# <Response [200]> 166
# <Response [200]> 167
# <Response [200]> 168
# <Response [200]> 169
# <Response [200]> 170
# <Response [200]> 171
# <Response [200]> 172
# <Response [200]> 173
# <Response [200]> 174
# <Response [200]> 175
# <Response [200]> 176
# <Response [200]> 177
# <Response [200]> 178
# <Response [200]> 179
# <Response [200]> 180
# <Response [200]> 181
# <Response [200]> 182
# <Response [200]> 183
# <Response [200]> 184
# <Response [200]> 185
# <Response [200]> 186
# <Response [200]> 187
# <Response [200]> 188
# <Response [200]> 189
# <Response [200]> 190
# <Response [200]> 191
# <Response [200]> 192
# <Response [200]> 193
# <Response [200]> 194
# <Response [200]> 195
# <Response [200]> 196
# <Response [200]> 197
# <Response [200]> 198
# <Response [200]> 199

# %%
print(json.dumps(result, indent=2))
# Out:
# [
#   {
#     "Price": "$1,850,000",
#     "Address": "2461 Fernleaf Ct NW, Atlanta, GA 30318",
#     "Realtor's Name": "JENNIFER HENLEY",
#     "Realtor's Email": "jennifer@beacham.com",
#     "Realtor's Phone": "4042817521",
#     "Brokered Name": "Beacham & Company REALTORS",
#     "Estimated Price": "$11,139 ",
#     "Property Type": "Single family",
#     "Days on Market": "7 hours",
#     "Year Built": "2025",
#     "Zip Code": "30318",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2461-Fernleaf-Ct-NW_Atlanta_GA_30318_M58104-12980"
#   },
#   {
#     "Price": "$2,249,900",
#     "Address": "48 25th St NW, Atlanta, GA 30309",
#     "Realtor's Name": "Chad Polazzo",
#     "Realtor's Email": "chadpolazzo@remax.net",
#     "Realtor's Phone": "4042267199",
#     "Brokered Name": "RE MAX Metro Atlanta Cityside",
#     "Estimated Price": "$12,807 ",
#     "Property Type": "Single family",
#     "Days on Market": "18 hours",
#     "Year Built": "2025",
#     "Zip Code": "30309",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/48-25th-St-NW_Atlanta_GA_30309_M98240-85408"
#   },
#   {
#     "Price": "$2,750,000",
#     "Address": "2425 Peachtree Rd NE Unit 1409, Atlanta, GA 30305",
#     "Realtor's Name": "Chase Mizell",
#     "Realtor's Email": "chasemizell@atlantafinehomes.com",
#     "Realtor's Phone": "4048740300",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$19,548 ",
#     "Property Type": "Condo",
#     "Days on Market": "7 hours",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2425-Peachtree-Rd-NE-Unit-1409_Atlanta_GA_30305_M93631-36639"
#   },
#   {
#     "Price": "$869,900",
#     "Address": "1055 Dryden Ln NE, Atlanta, GA 30319",
#     "Realtor's Name": "Preserve at Lenox Park",
#     "Realtor's Email": null,
#     "Realtor's Phone": "N/A",
#     "Brokered Name": "N/A",
#     "Estimated Price": "$4,936 ",
#     "Property Type": "Townhomes",
#     "Days on Market": null,
#     "Year Built": null,
#     "Zip Code": "N/A",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1055-Dryden-Ln-NE_Brookhaven_GA_30319_M94833-43770",
#     "error": "'NoneType' object is not subscriptable"
#   },
#   {
#     "Price": "$1,361,000",
#     "Address": "N/A",
#     "Realtor's Name": "Waterford at Briarcliff",
#     "Realtor's Email": null,
#     "Realtor's Phone": "N/A",
#     "Brokered Name": "N/A",
#     "Estimated Price": "$8,801 ",
#     "Property Type": "Single family",
#     "Days on Market": null,
#     "Year Built": null,
#     "Zip Code": "N/A",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/Chadwick_Waterford-at-Briarcliff_4046-Briarcliff-Road_Atlanta_GA_30345_P417000811629",
#     "error": "'NoneType' object is not subscriptable"
#   },
#   {
#     "Price": "$3,500,000",
#     "Address": "6531 Long Acres Dr, Atlanta, GA 30328",
#     "Realtor's Name": "Jodi Mekyten",
#     "Realtor's Email": "jodi.mekyten@bhhsga.com",
#     "Realtor's Phone": "7703744500",
#     "Brokered Name": "Berkshire Hathaway HomeServices Georgia Properties",
#     "Estimated Price": "$19,512 ",
#     "Property Type": "Single family",
#     "Days on Market": "11 days",
#     "Year Built": "2025",
#     "Zip Code": "30328",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/6531-Long-Acres-Dr_Atlanta_GA_30328_M99592-79328"
#   },
#   {
#     "Price": "$9,650,000",
#     "Address": "840 N Island Dr, Sandy Springs, GA 30327",
#     "Realtor's Name": "Nicholas Daniel Brown",
#     "Realtor's Email": "nicholas.brown@compass.com",
#     "Realtor's Phone": "7706305430",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$54,462 ",
#     "Property Type": "Single family",
#     "Days on Market": "181 days",
#     "Year Built": "2024",
#     "Zip Code": "30327",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/840-N-Island-Dr_Atlanta_GA_30327_M61033-89596"
#   },
#   {
#     "Price": "$2,900,000",
#     "Address": "1445 W Wesley Rd NE, Atlanta, GA 30327",
#     "Realtor's Name": "George Heery",
#     "Realtor's Email": "george.heery@atlantafinehomes.com",
#     "Realtor's Phone": "4042375000",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$16,475 ",
#     "Property Type": "Single family",
#     "Days on Market": "7 days",
#     "Year Built": "2025",
#     "Zip Code": "30327",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1445-W-Wesley-Rd-NE_Atlanta_GA_30327_M94304-01294"
#   },
#   {
#     "Price": "$2,800,000",
#     "Address": "1410 Lavista Rd NE, Atlanta, GA 30324",
#     "Realtor's Name": "Courtney Phillips",
#     "Realtor's Email": "cphillips1028@gmail.com",
#     "Realtor's Phone": "4043759461",
#     "Brokered Name": "Exp Realty LLC",
#     "Estimated Price": "$18,740 ",
#     "Property Type": "Single family",
#     "Days on Market": "63 days",
#     "Year Built": "2025",
#     "Zip Code": "30324",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1410-Lavista-Rd-NE_Atlanta_GA_30324_M61256-65704"
#   },
#   {
#     "Price": "$1,495,000",
#     "Address": "3220 Osborne Rd NE, Atlanta, GA 30319",
#     "Realtor's Name": "Inna  Eidelman",
#     "Realtor's Email": "inna@setrealestategroup.com",
#     "Realtor's Phone": "4049323330",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$8,760 ",
#     "Property Type": "Single family",
#     "Days on Market": "20 days",
#     "Year Built": "2025",
#     "Zip Code": "30319",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3220-Osborne-Rd-NE_Brookhaven_GA_30319_M68941-78491"
#   },
#   {
#     "Price": "$4,495,000",
#     "Address": "42 Blackland Rd NW, Atlanta, GA 30342",
#     "Realtor's Name": "Bonneau Ansley",
#     "Realtor's Email": "bonneau@ansleyatlanta.com",
#     "Realtor's Phone": "4049063161",
#     "Brokered Name": "Ansley Real Estate | Christie's International Real Estate",
#     "Estimated Price": "$25,789 ",
#     "Property Type": "Single family",
#     "Days on Market": "68 days",
#     "Year Built": "2024",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/42-Blackland-Rd-NW_Atlanta_GA_30342_M60003-89680"
#   },
#   {
#     "Price": "$5,999,000",
#     "Address": "5271 Lake Forrest Dr, Atlanta, GA 30342",
#     "Realtor's Name": "Kelly Loudermilk",
#     "Realtor's Email": "roaneloudermilk@hotmail.com",
#     "Realtor's Phone": "(404) 236-0043",
#     "Brokered Name": "KELLER WILLIAMS REALTY BUCKHEAD",
#     "Estimated Price": "$33,997 ",
#     "Property Type": "Single family",
#     "Days on Market": "97 days",
#     "Year Built": "2024",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/5271-Lake-Forrest-Dr_Atlanta_GA_30342_M53184-01227"
#   },
#   {
#     "Price": "$5,295,000",
#     "Address": "96 The Prado NE, Atlanta, GA 30309",
#     "Realtor's Name": "JIM GETZINGER",
#     "Realtor's Email": "jim@getzingergroup.com",
#     "Realtor's Phone": "4043074020",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$30,229 ",
#     "Property Type": "Single family",
#     "Days on Market": "18 days",
#     "Year Built": "2025",
#     "Zip Code": "30309",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/96-The-Prado-NE_Atlanta_GA_30309_M51136-08089"
#   },
#   {
#     "Price": "$2,250,000",
#     "Address": "4152 Club Dr NE, Atlanta, GA 30319",
#     "Realtor's Name": "Kristen Sodemann",
#     "Realtor's Email": "kristensodemann@beacham.com",
#     "Realtor's Phone": "4043100608",
#     "Brokered Name": "Home Real Estate, LLC",
#     "Estimated Price": "$15,742 ",
#     "Property Type": "Single family",
#     "Days on Market": "3 days",
#     "Year Built": "2024",
#     "Zip Code": "30319",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4152-Club-Dr-NE_Atlanta_GA_30319_M53891-74326"
#   },
#   {
#     "Price": "$5,950,000",
#     "Address": "1235 Mount Paran Rd NW, Atlanta, GA 30327",
#     "Realtor's Name": "Bonneau Ansley",
#     "Realtor's Email": "bonneau@ansleyatlanta.com",
#     "Realtor's Phone": "4049063161",
#     "Brokered Name": "Ansley Real Estate",
#     "Estimated Price": "$33,757 ",
#     "Property Type": "Single family",
#     "Days on Market": "273 days",
#     "Year Built": "2024",
#     "Zip Code": "30327",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1235-Mount-Paran-Rd-NW_Atlanta_GA_30327_M58445-59956"
#   },
#   {
#     "Price": "$1,149,000",
#     "Address": "993 Northrope Dr NE, Atlanta, GA 30324",
#     "Realtor's Name": "George Heery",
#     "Realtor's Email": "george.heery@atlantafinehomes.com",
#     "Realtor's Phone": "4042375000",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$7,050 ",
#     "Property Type": "Single family",
#     "Days on Market": "32 days",
#     "Year Built": "2025",
#     "Zip Code": "30324",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/993-Northrope-Dr-NE_Atlanta_GA_30324_M68671-97428"
#   },
#   {
#     "Price": "$1,249,900",
#     "Address": "262 Green Hill Rd NE, Sandy Springs, GA 30342",
#     "Realtor's Name": "Heather Shipp Team",
#     "Realtor's Email": "heathershipp@jennpruitt.com",
#     "Realtor's Phone": "4044099427",
#     "Brokered Name": "Ansley Real Estate",
#     "Estimated Price": "$8,363 ",
#     "Property Type": "Single family",
#     "Days on Market": "35 days",
#     "Year Built": "2025",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/262-Green-Hill-Rd_Atlanta_GA_30342_M94169-50923"
#   },
#   {
#     "Price": "$9,250,000",
#     "Address": "41 Blackland Rd NW, Atlanta, GA 30342",
#     "Realtor's Name": "Katie Brannen",
#     "Realtor's Email": "katie.brannen@harrynorman.com",
#     "Realtor's Phone": "4048080881",
#     "Brokered Name": "Ansley Real Estate | Christie's International Real Estate",
#     "Estimated Price": "$52,006 ",
#     "Property Type": "Single family",
#     "Days on Market": "33 days",
#     "Year Built": "2025",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/41-Blackland-Rd-NW_Atlanta_GA_30342_M52801-29990"
#   },
#   {
#     "Price": "$2,490,000",
#     "Address": "247 Huntington Rd NE, Atlanta, GA 30309",
#     "Realtor's Name": "Brett Ross",
#     "Realtor's Email": "brett.ross@kw.com",
#     "Realtor's Phone": "7704024125",
#     "Brokered Name": "KELLER WILLIAMS REALTY FIRST ATLANTA",
#     "Estimated Price": "$14,293 ",
#     "Property Type": "Single family",
#     "Days on Market": "120 days",
#     "Year Built": "2024",
#     "Zip Code": "30309",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/247-Huntington-Rd-NE_Atlanta_GA_30309_M94096-46354"
#   },
#   {
#     "Price": "$2,995,000",
#     "Address": "2413 Spalding Dr, Atlanta, GA 30350",
#     "Realtor's Name": "David Goodrowe",
#     "Realtor's Email": "david.goodrowe@compass.com",
#     "Realtor's Phone": "4043333190",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$16,708 ",
#     "Property Type": "Single family",
#     "Days on Market": "12 days",
#     "Year Built": "2024",
#     "Zip Code": "30350",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2413-Spalding-Dr_Atlanta_GA_30350_M97876-44319"
#   },
#   {
#     "Price": "$2,625,000",
#     "Address": "748 Charles Allen Dr NE, Atlanta, GA 30308",
#     "Realtor's Name": "Matthew Doyle",
#     "Realtor's Email": "matthew.doyle@compass.com",
#     "Realtor's Phone": "5617076139",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$14,855 ",
#     "Property Type": "Single family",
#     "Days on Market": "181 days",
#     "Year Built": "2024",
#     "Zip Code": "30308",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/748-Charles-Allen-Dr-NE_Atlanta_GA_30308_M54080-34929"
#   },
#   {
#     "Price": "$4,000,000",
#     "Address": "55 Serendipity Way, Sandy Springs, GA 30350",
#     "Realtor's Name": "Toshia Glover",
#     "Realtor's Email": "toshsellsfast@gmail.com",
#     "Realtor's Phone": "(404) 771-2032",
#     "Brokered Name": "Elevate Real Estate LLC",
#     "Estimated Price": "$23,271 ",
#     "Property Type": "Single family",
#     "Days on Market": "95 days",
#     "Year Built": "2023",
#     "Zip Code": "30350",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/55-Serendipity-Way_Atlanta_GA_30350_M56860-23145"
#   },
#   {
#     "Price": "$3,995,000",
#     "Address": "3566 Cantrell Rd NE, Atlanta, GA 30319",
#     "Realtor's Name": "Mike Toltzis",
#     "Realtor's Email": "mike.toltzis@coldwellbankeratlanta.com",
#     "Realtor's Phone": "4043769135",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$23,964 ",
#     "Property Type": "Single family",
#     "Days on Market": "98 days",
#     "Year Built": "2025",
#     "Zip Code": "30319",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3566-Cantrell-Rd-NE_Atlanta_GA_30319_M52091-00217"
#   },
#   {
#     "Price": "$2,895,000",
#     "Address": "530 Old Cobblestone Dr, Atlanta, GA 30350",
#     "Realtor's Name": "Charles Guthrie",
#     "Realtor's Email": "charlesguthrie@dorseyalston.com",
#     "Realtor's Phone": "4043522010",
#     "Brokered Name": "Dorsey Alston Realtors",
#     "Estimated Price": "$16,704 ",
#     "Property Type": "Single family",
#     "Days on Market": "20 days",
#     "Year Built": "2025",
#     "Zip Code": "30350",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/530-Old-Cobblestone-Dr_Atlanta_GA_30350_M65242-71730"
#   },
#   {
#     "Price": "$2,250,000",
#     "Address": "4895 Lansbury Dr, Atlanta, GA 30342",
#     "Realtor's Name": "AMY FRENCH",
#     "Realtor's Email": "",
#     "Realtor's Phone": "4043260063",
#     "Brokered Name": "Ansley Real Estate | Christie's International Real Estate",
#     "Estimated Price": "$13,141 ",
#     "Property Type": "Single family",
#     "Days on Market": "60 days",
#     "Year Built": "2024",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4895-Lansbury-Dr_Atlanta_GA_30342_M66721-37335"
#   },
#   {
#     "Price": "$1,895,000",
#     "Address": "198 Johnson Ferry Rd NW, Atlanta, GA 30328",
#     "Realtor's Name": "SHANNA BRADLEY",
#     "Realtor's Email": "shanna@ansleyre.com",
#     "Realtor's Phone": "4048086295",
#     "Brokered Name": "Ansley Real Estate | Christie's International Real Estate",
#     "Estimated Price": "$11,053 ",
#     "Property Type": "Single family",
#     "Days on Market": "53 days",
#     "Year Built": "2024",
#     "Zip Code": "30328",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/198-Johnson-Ferry-Rd-NW_Atlanta_GA_30328_M55117-35897"
#   },
#   {
#     "Price": "$2,599,000",
#     "Address": "4132 Carmain Dr NE, Atlanta, GA 30342",
#     "Realtor's Name": "Keith Wells",
#     "Realtor's Email": "keith.wells@exprealty.com",
#     "Realtor's Phone": "4044383149",
#     "Brokered Name": "Exp Realty LLC",
#     "Estimated Price": "$15,325 ",
#     "Property Type": "Single family",
#     "Days on Market": "56 days",
#     "Year Built": "2022",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4132-Carmain-Dr-NE_Atlanta_GA_30342_M51198-22391"
#   },
#   {
#     "Price": "$4,500,000",
#     "Address": "3939 Ivy Rd NE, Atlanta, GA 30342",
#     "Realtor's Name": "Matthew Doyle",
#     "Realtor's Email": "matthew.doyle@compass.com",
#     "Realtor's Phone": "5617076139",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$25,151 ",
#     "Property Type": "Single family",
#     "Days on Market": "67 days",
#     "Year Built": "2025",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3939-Ivy-Rd-NE_Atlanta_GA_30342_M55358-40664"
#   },
#   {
#     "Price": "$2,239,000",
#     "Address": "6175 River Shore Pkwy, Atlanta, GA 30328",
#     "Realtor's Name": "Harry Angevine",
#     "Realtor's Email": "900614.lead.lag.100132394@cendant.leadrouter.com",
#     "Realtor's Phone": "(404) 495-4680",
#     "Brokered Name": "Dorsey Alston Realtors",
#     "Estimated Price": "$12,947 ",
#     "Property Type": "Single family",
#     "Days on Market": "214 days",
#     "Year Built": "2024",
#     "Zip Code": "30328",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/6175-River-Shore-Pkwy_Atlanta_GA_30328_M66150-62359"
#   },
#   {
#     "Price": "$6,995,000",
#     "Address": "2515 Habersham Rd NW, Atlanta, GA 30305",
#     "Realtor's Name": "ROBERT PETERSON",
#     "Realtor's Email": "robertpeterson@dorseyalston.com",
#     "Realtor's Phone": "(404) 668-7210",
#     "Brokered Name": "Dorsey Alston Realtors",
#     "Estimated Price": "$41,033 ",
#     "Property Type": "Single family",
#     "Days on Market": "20 days",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2515-Habersham-Rd-NW_Atlanta_GA_30305_M62495-92816"
#   },
#   {
#     "Price": "$4,300,000",
#     "Address": "4524 Mystic Dr, Sandy Springs, GA 30342",
#     "Realtor's Name": "MARCIA K WEINHOFF",
#     "Realtor's Email": "marcia.weinhoff@harrynorman.com",
#     "Realtor's Phone": "4049830309",
#     "Brokered Name": "Harry Norman, REALTORS\u00ae - Atlanta Perimeter",
#     "Estimated Price": "$24,211 ",
#     "Property Type": "Single family",
#     "Days on Market": "41 days",
#     "Year Built": "2025",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4524-Mystic-Dr_Atlanta_GA_30342_M52404-04496"
#   },
#   {
#     "Price": "$2,950,000",
#     "Address": "464 Pine Tree Dr NE, Atlanta, GA 30305",
#     "Realtor's Name": "Nadine Chamseddine",
#     "Realtor's Email": "nchamseddine@yahoo.com",
#     "Realtor's Phone": "7707135449",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$17,001 ",
#     "Property Type": "Single family",
#     "Days on Market": "7 days",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/464-Pine-Tree-Dr-NE_Atlanta_GA_30305_M60641-78641"
#   },
#   {
#     "Price": "$4,350,000",
#     "Address": "825 Kenry Ct, Atlanta, GA 30342",
#     "Realtor's Name": "KELLY BOUDREAU",
#     "Realtor's Email": "Kelly@HOMEGeorgia.com",
#     "Realtor's Phone": "4044560536",
#     "Brokered Name": "Home Real Estate, LLC",
#     "Estimated Price": "$24,635 ",
#     "Property Type": "Single family",
#     "Days on Market": "301 days",
#     "Year Built": "2024",
#     "Zip Code": "30342",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/825-Kenry-Ct_Atlanta_GA_30342_M92039-57458"
#   },
#   {
#     "Price": "$1,638,000",
#     "Address": "337 Pine St NE, Atlanta, GA 30308",
#     "Realtor's Name": "Adriana Herrera",
#     "Realtor's Email": "adriana.herrera@cbrealty.com",
#     "Realtor's Phone": "4048742262",
#     "Brokered Name": "METHOD REAL ESTATE ADVISORS",
#     "Estimated Price": "$9,691 ",
#     "Property Type": "Multi-Family",
#     "Days on Market": "84 days",
#     "Year Built": "2024",
#     "Zip Code": "30308",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/337-Pine-St-NE_Atlanta_GA_30308_M58267-79026"
#   },
#   {
#     "Price": "$2,295,000",
#     "Address": "340 Colewood Way, Atlanta, GA 30328",
#     "Realtor's Name": "Harry Angevine",
#     "Realtor's Email": "900614.lead.lag.100132394@cendant.leadrouter.com",
#     "Realtor's Phone": "(404) 495-4680",
#     "Brokered Name": "Dorsey Alston Realtors",
#     "Estimated Price": "$13,591 ",
#     "Property Type": "Single family",
#     "Days on Market": "126 days",
#     "Year Built": "2024",
#     "Zip Code": "30328",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/340-Colewood-Way_Atlanta_GA_30328_M62018-69664"
#   },
#   {
#     "Price": "$932,838",
#     "Address": "1059 Dryden Ln NE Unit 11, Atlanta, GA 30319",
#     "Realtor's Name": "Tracie Bernstein",
#     "Realtor's Email": "tbernstein@theprovidencegroup.com",
#     "Realtor's Phone": "7703158413",
#     "Brokered Name": "Ea Brokerage Llc",
#     "Estimated Price": "$6,416 ",
#     "Property Type": "Townhomes",
#     "Days on Market": "4 days",
#     "Year Built": "2024",
#     "Zip Code": "30319",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1059-Dryden-Ln-NE-11_Brookhaven_GA_30319_M95521-33324"
#   },
#   {
#     "Price": "$1,500,000",
#     "Address": "40 12th St NE Unit 1004, Atlanta, GA 30309",
#     "Realtor's Name": "Susie Proffitt",
#     "Realtor's Email": "Susie.Proffitt@ColdwellBankerAtlanta.com",
#     "Realtor's Phone": "4049159367",
#     "Brokered Name": "Engel & Volkers Atlanta",
#     "Estimated Price": "$12,658 ",
#     "Property Type": "Condo",
#     "Days on Market": "81 days",
#     "Year Built": "2021",
#     "Zip Code": "30309",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/40-12th-St-NE-Unit-1004_Atlanta_GA_30309_M93015-65891"
#   },
#   {
#     "Price": "$2,995,000",
#     "Address": "3680 Tanglewood Dr SE, Atlanta, GA 30339",
#     "Realtor's Name": "Brian McDaniel",
#     "Realtor's Email": "kwbmc@aol.com",
#     "Realtor's Phone": "7705090700",
#     "Brokered Name": "Keller Williams Realty Atlanta - East Cobb",
#     "Estimated Price": "$17,191 ",
#     "Property Type": "Single family",
#     "Days on Market": "41 days",
#     "Year Built": "2025",
#     "Zip Code": "30339",
#     "Multi Listings": 3,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3680-Tanglewood-Dr-SE_Atlanta_GA_30339_M58964-46744"
#   },
#   {
#     "Price": "$1,748,000",
#     "Address": "114 Terrace Dr NE, Atlanta, GA 30305",
#     "Realtor's Name": "Chad Polazzo",
#     "Realtor's Email": "chadpolazzo@remax.net",
#     "Realtor's Phone": "4042267199",
#     "Brokered Name": "RE MAX Metro Atlanta Cityside",
#     "Estimated Price": "$10,094 ",
#     "Property Type": "Single family",
#     "Days on Market": "64 days",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/114-Terrace-Dr-NE_Atlanta_GA_30305_M98729-86738"
#   },
#   {
#     "Price": "$1,850,000",
#     "Address": "Kingsboro Rd Unit 1, Atlanta, GA 30326",
#     "Realtor's Name": "George Heery",
#     "Realtor's Email": "george.heery@atlantafinehomes.com",
#     "Realtor's Phone": "4042375000",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$12,523 ",
#     "Property Type": "Townhomes",
#     "Days on Market": "69 days",
#     "Year Built": "2025",
#     "Zip Code": "30326",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1-Kingston-Mnr_Atlanta_GA_30342_M97925-99309"
#   },
#   {
#     "Price": "$2,150,000",
#     "Address": "1445 Ashwoody Ct NE, Atlanta, GA 30319",
#     "Realtor's Name": "Aziz Izmour",
#     "Realtor's Email": "aziz.izmour@compass.com",
#     "Realtor's Phone": "4049015662",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$12,578 ",
#     "Property Type": "Single family",
#     "Days on Market": "62 days",
#     "Year Built": "2025",
#     "Zip Code": "30319",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1445-Ashwoody-Ct-NE_Brookhaven_GA_30319_M64805-52423"
#   },
#   {
#     "Price": "$2,415,000",
#     "Address": "225 River Valley Ct Lot 5, Atlanta, GA 30328",
#     "Realtor's Name": "Nicholas Daniel Brown",
#     "Realtor's Email": "nicholas.brown@compass.com",
#     "Realtor's Phone": "7706305430",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$16,160 ",
#     "Property Type": "Single family",
#     "Days on Market": "413 days",
#     "Year Built": "2024",
#     "Zip Code": "30328",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/225-River-Valley-Ct-5_Sandy-Springs_GA_30328_M99106-80763"
#   },
#   {
#     "Price": "$2,095,000",
#     "Address": "270 Crosstree Ln, Atlanta, GA 30328",
#     "Realtor's Name": null,
#     "Realtor's Email": null,
#     "Realtor's Phone": "N/A",
#     "Brokered Name": "N/A",
#     "Estimated Price": "$11,960 ",
#     "Property Type": "Single family",
#     "Days on Market": "290 days",
#     "Year Built": "2024",
#     "Zip Code": "N/A",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/270-Crosstree-Ln_Atlanta_GA_30328_M55984-91011",
#     "error": "'NoneType' object is not subscriptable"
#   },
#   {
#     "Price": "$5,495,000",
#     "Address": "1107 E Beechwood Dr NW, Atlanta, GA 30327",
#     "Realtor's Name": "Will Letton",
#     "Realtor's Email": "willletton@atlantafinehomes.com",
#     "Realtor's Phone": "4048740300",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$32,373 ",
#     "Property Type": "Single family",
#     "Days on Market": "203 days",
#     "Year Built": "2024",
#     "Zip Code": "30327",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1107-E-Beechwood-Dr-NW_Atlanta_GA_30327_M60500-81629"
#   },
#   {
#     "Price": "$2,399,000",
#     "Address": "3790 Ivy Rd NE, Atlanta, GA 30342",
#     "Realtor's Name": "Ryan Abbe",
#     "Realtor's Email": "ryanabbe@c21connectrealty.com",
#     "Realtor's Phone": "7706406800",
#     "Brokered Name": "CENTURY 21 Connect Realty",
#     "Estimated Price": "$13,511 ",
#     "Property Type": "Single family",
#     "Days on Market": "118 days",
#     "Year Built": "2024",
#     "Zip Code": "30342",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3790-Ivy-Rd-NE_Atlanta_GA_30342_M57375-26053"
#   },
#   {
#     "Price": "$4,150,000",
#     "Address": "2425 Peachtree Rd NE Unit 1806, Atlanta, GA 30305",
#     "Realtor's Name": "Heather Shipp Team",
#     "Realtor's Email": "heathershipp@jennpruitt.com",
#     "Realtor's Phone": "4044099427",
#     "Brokered Name": "Ansley Real Estate | Christie's International Real Estate",
#     "Estimated Price": "$29,372 ",
#     "Property Type": "Condo",
#     "Days on Market": "63 days",
#     "Year Built": "2025",
#     "Zip Code": "30305",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2425-Peachtree-Rd-NE-Unit-1806_Atlanta_GA_30305_M90687-28074"
#   },
#   {
#     "Price": "$3,000,000",
#     "Address": "555 Orme Cir NE, Atlanta, GA 30306",
#     "Realtor's Name": "Jason Wieloch",
#     "Realtor's Email": "jason.wieloch@compass.com",
#     "Realtor's Phone": "4045181368",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$17,755 ",
#     "Property Type": "Single family",
#     "Days on Market": "18 days",
#     "Year Built": "2025",
#     "Zip Code": "30306",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/555-Orme-Cir-NE_Atlanta_GA_30306_M59546-93411"
#   },
#   {
#     "Price": "$3,495,000",
#     "Address": "1026 Reeder Cir NE, Atlanta, GA 30306",
#     "Realtor's Name": "Jared Sapp",
#     "Realtor's Email": "jared@atlantafinehomes.com",
#     "Realtor's Phone": "4042375000",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$20,172 ",
#     "Property Type": "Single family",
#     "Days on Market": "358 days",
#     "Year Built": "2024",
#     "Zip Code": "30306",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1026-Reeder-Cir-NE_Atlanta_GA_30306_M51512-51063"
#   },
#   {
#     "Price": "$1,200,000",
#     "Address": "1045 Shepherds Ln NE, Atlanta, GA 30324",
#     "Realtor's Name": "Bryan Gates",
#     "Realtor's Email": "bryan@bryanmgates.com",
#     "Realtor's Phone": "7707133761",
#     "Brokered Name": "Real Broker LLC",
#     "Estimated Price": "$7,557 ",
#     "Property Type": "Single family",
#     "Days on Market": "21 days",
#     "Year Built": "2018",
#     "Zip Code": "30324",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1045-Shepherds-Ln-NE_Atlanta_GA_30324_M60886-23357"
#   },
#   {
#     "Price": "$919,000",
#     "Address": "192 E Lake Ter SE, Atlanta, GA 30317",
#     "Realtor's Name": "Sara Lee Parker & Associates",
#     "Realtor's Email": "saralee@saraleeparker.com",
#     "Realtor's Phone": "4049208600",
#     "Brokered Name": "Keller Williams Realty Intown",
#     "Estimated Price": "$5,786 ",
#     "Property Type": "Single family",
#     "Days on Market": "89 days",
#     "Year Built": "2024",
#     "Zip Code": "30317",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/192-E-Lake-Ter-SE_Atlanta_GA_30317_M93184-85715"
#   },
#   {
#     "Price": "$849,900",
#     "Address": "648 Liella Park SE, Atlanta, GA 30312",
#     "Realtor's Name": "Ryan Sconyers",
#     "Realtor's Email": "ryan@sconyerscompany.com",
#     "Realtor's Phone": "4044273778",
#     "Brokered Name": "Keller Williams Realty Intown",
#     "Estimated Price": "$4,875 ",
#     "Property Type": "Single family",
#     "Days on Market": "56 days",
#     "Year Built": "2024",
#     "Zip Code": "30312",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/648-Liella-Park-SE_Atlanta_GA_30312_M98609-73583"
#   },
#   {
#     "Price": "$1,700,000",
#     "Address": "431 Clifton Rd NE, Atlanta, GA 30307",
#     "Realtor's Name": "Hector Pineyro",
#     "Realtor's Email": "pineyroatl@gmail.com",
#     "Realtor's Phone": "4049217160",
#     "Brokered Name": "HomeSmart",
#     "Estimated Price": "$9,527 ",
#     "Property Type": "Single family",
#     "Days on Market": "27 days",
#     "Year Built": "2024",
#     "Zip Code": "30307",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/431-Clifton-Rd-NE_Atlanta_GA_30307_M90388-89801"
#   },
#   {
#     "Price": "$1,700,000",
#     "Address": "431 Clifton Rd NE, Atlanta, GA 30307",
#     "Realtor's Name": "Hector Pineyro",
#     "Realtor's Email": "pineyroatl@gmail.com",
#     "Realtor's Phone": "4049217160",
#     "Brokered Name": "HomeSmart",
#     "Estimated Price": "$9,991 ",
#     "Property Type": "Single family",
#     "Days on Market": "25 days",
#     "Year Built": "2024",
#     "Zip Code": "30307",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/431-Clifton-Rd-NE_Atlanta_GA_30307_M63931-42970"
#   },
#   {
#     "Price": "$2,499,000",
#     "Address": "239 E Wesley Rd NE, Atlanta, GA 30305",
#     "Realtor's Name": "William Omeara",
#     "Realtor's Email": "c45@leadgen.reliancenetwork.com",
#     "Realtor's Phone": "4043486568",
#     "Brokered Name": "Berkshire Hathaway HomeServices Georgia Properties",
#     "Estimated Price": "$14,903 ",
#     "Property Type": "Single family",
#     "Days on Market": "40 days",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/239-E-Wesley-Rd-NE_Atlanta_GA_30305_M50314-48058"
#   },
#   {
#     "Price": "$2,750,000",
#     "Address": "1291 Sunderland Ct NE, Atlanta, GA 30319",
#     "Realtor's Name": "Craig Dodd",
#     "Realtor's Email": "craigdodd@atlantafinehomes.com",
#     "Realtor's Phone": "4042375000",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$15,276 ",
#     "Property Type": "Single family",
#     "Days on Market": "27 days",
#     "Year Built": "2025",
#     "Zip Code": "30319",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1291-Sunderland-Ct-NE_Brookhaven_GA_30319_M58421-49562"
#   },
#   {
#     "Price": "$2,599,000",
#     "Address": "1277 Avalon Pl NE, Atlanta, GA 30306",
#     "Realtor's Name": "Jonathan Rich",
#     "Realtor's Email": "jrich@kellerknapp.com",
#     "Realtor's Phone": "7704023957",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$15,344 ",
#     "Property Type": "Single family",
#     "Days on Market": "221 days",
#     "Year Built": "2024",
#     "Zip Code": "30306",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1277-Avalon-Pl-NE_Atlanta_GA_30306_M52849-23998"
#   },
#   {
#     "Price": "$1,349,900",
#     "Address": "1039 Avondale Ave SE, Atlanta, GA 30312",
#     "Realtor's Name": "Brittany Miller",
#     "Realtor's Email": "brittany@dreamcatcherrealtygrp.com",
#     "Realtor's Phone": "4048252650",
#     "Brokered Name": "Coldwell Banker Realty",
#     "Estimated Price": "$7,681 ",
#     "Property Type": "Single family",
#     "Days on Market": "27 days",
#     "Year Built": "2024",
#     "Zip Code": "30312",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1039-Avondale-Ave-SE_Atlanta_GA_30312_M97466-70214"
#   },
#   {
#     "Price": "$1,900,000",
#     "Address": "4408 Brookview Dr SE, Atlanta, GA 30339",
#     "Realtor's Name": "Susan M Protos",
#     "Realtor's Email": "sprotos.homesmart@gmail.com",
#     "Realtor's Phone": "4047711791",
#     "Brokered Name": "HomeSmart",
#     "Estimated Price": "$11,125 ",
#     "Property Type": "Single family",
#     "Days on Market": "368 days",
#     "Year Built": "2024",
#     "Zip Code": "30339",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4408-Brookview-Dr-SE_Atlanta_GA_30339_M90190-20036"
#   },
#   {
#     "Price": "$945,000",
#     "Address": "387 S Howard St SE, Atlanta, GA 30317",
#     "Realtor's Name": "Michelle Wilson",
#     "Realtor's Email": "michelle.wilson@coldwellbankeratlanta.com",
#     "Realtor's Phone": "7706231900",
#     "Brokered Name": "Coldwell Banker Realty",
#     "Estimated Price": "$5,597 ",
#     "Property Type": "Single family",
#     "Days on Market": "18 days",
#     "Year Built": "2024",
#     "Zip Code": "30317",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/387-S-Howard-St-SE_Atlanta_GA_30317_M66240-65493"
#   },
#   {
#     "Price": "$1,499,000",
#     "Address": "1134 Country Ln NE, Atlanta, GA 30324",
#     "Realtor's Name": "Maximillian Corwell",
#     "Realtor's Email": "max@corwellfinehomes.com",
#     "Realtor's Phone": "(404) 216-4816",
#     "Brokered Name": "Keller Williams Realty Intown",
#     "Estimated Price": "$8,614 ",
#     "Property Type": "Single family",
#     "Days on Market": "83 days",
#     "Year Built": "2024",
#     "Zip Code": "30324",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1134-Country-Ln-NE_Atlanta_GA_30324_M61099-76742"
#   },
#   {
#     "Price": "$2,300,000",
#     "Address": "904 Kings Ct NE, Atlanta, GA 30306",
#     "Realtor's Name": "JEANNETTE M FELDER",
#     "Realtor's Email": "jettluxuryhomes@gmail.com",
#     "Realtor's Phone": "(678) 464-5013",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$13,278 ",
#     "Property Type": "Single family",
#     "Days on Market": "33 days",
#     "Year Built": "2025",
#     "Zip Code": "30306",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/904-Kings-Ct-NE_Atlanta_GA_30306_M51339-61591"
#   },
#   {
#     "Price": "$2,450,000",
#     "Address": "1281 Avalon Pl NE, Atlanta, GA 30306",
#     "Realtor's Name": "Jonathan Rich",
#     "Realtor's Email": "jrich@kellerknapp.com",
#     "Realtor's Phone": "7704023957",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$14,056 ",
#     "Property Type": "Single family",
#     "Days on Market": "166 days",
#     "Year Built": "2024",
#     "Zip Code": "30306",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1281-Avalon-Pl-NE_Atlanta_GA_30306_M52106-63125"
#   },
#   {
#     "Price": "$1,229,000",
#     "Address": "567 Ponce De Leon Ave NE Unit 501, Atlanta, GA 30308",
#     "Realtor's Name": "Allyson Golightly",
#     "Realtor's Email": "golightlyally@gmail.com",
#     "Realtor's Phone": "4042345989",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$9,026 ",
#     "Property Type": "Condo",
#     "Days on Market": "22 days",
#     "Year Built": "2025",
#     "Zip Code": "30308",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/567-Ponce-De-Leon-Ave-NE-501_Atlanta_GA_30308_M93214-59859"
#   },
#   {
#     "Price": "$1,225,000",
#     "Address": "1137 Hardee St NE Unit B, Atlanta, GA 30307",
#     "Realtor's Name": "Barbara Spiller",
#     "Realtor's Email": "bobbie@eketsa.com",
#     "Realtor's Phone": "4047485988",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$7,288 ",
#     "Property Type": "Townhomes",
#     "Days on Market": "61 days",
#     "Year Built": "2025",
#     "Zip Code": "30307",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1137-Hardee-St-NE-B_Atlanta_GA_30307_M93097-23233"
#   },
#   {
#     "Price": "$2,495,000",
#     "Address": "581 Sherwood Rd NE, Atlanta, GA 30324",
#     "Realtor's Name": "ELENA GIST",
#     "Realtor's Email": "ELENAGIST@YAHOO.COM",
#     "Realtor's Phone": "4042720812",
#     "Brokered Name": "KELLER WILLIAMS REALTY BUCKHEAD",
#     "Estimated Price": "$14,756 ",
#     "Property Type": "Single family",
#     "Days on Market": "34 days",
#     "Year Built": "2025",
#     "Zip Code": "30324",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/581-Sherwood-Rd-NE_Atlanta_GA_30324_M54648-30487"
#   },
#   {
#     "Price": "$2,995,000",
#     "Address": "2425 Peachtree Rd NW Unit 1802, Atlanta, GA 30305",
#     "Realtor's Name": "Glennis Beacham",
#     "Realtor's Email": "glennisbeacham@beacham.com",
#     "Realtor's Phone": "4042619036",
#     "Brokered Name": "Beacham & Company REALTORS",
#     "Estimated Price": "$20,040 ",
#     "Property Type": "Condo",
#     "Days on Market": "50 days",
#     "Year Built": "2025",
#     "Zip Code": "30305",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2425-Peachtree-Rd-NW-Unit-1802_Atlanta_GA_30305_M92641-19858"
#   },
#   {
#     "Price": "$936,705",
#     "Address": "2249 Addington Way NE, Atlanta, GA 30319",
#     "Realtor's Name": "Preserve at Lenox Park",
#     "Realtor's Email": null,
#     "Realtor's Phone": "N/A",
#     "Brokered Name": "N/A",
#     "Estimated Price": "$5,306 ",
#     "Property Type": "Townhomes",
#     "Days on Market": null,
#     "Year Built": null,
#     "Zip Code": "N/A",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2249-Addington-Way-NE_Brookhaven_GA_30319_M94488-95766",
#     "error": "'NoneType' object is not subscriptable"
#   },
#   {
#     "Price": "$814,900",
#     "Address": "185 Marion Pl NE Unit A, Atlanta, GA 30307",
#     "Realtor's Name": "Jonathan Rich",
#     "Realtor's Email": "jrich@kellerknapp.com",
#     "Realtor's Phone": "7704023957",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$5,269 ",
#     "Property Type": "Townhomes",
#     "Days on Market": "33 days",
#     "Year Built": "2024",
#     "Zip Code": "30307",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/185-Marion-Pl-NE-A_Atlanta_GA_30307_M93856-48846"
#   },
#   {
#     "Price": "$2,075,000",
#     "Address": "727 Berkeley Ave NW, Atlanta, GA 30318",
#     "Realtor's Name": "Stephen Freudenberg",
#     "Realtor's Email": "stephen@knock.co",
#     "Realtor's Phone": "4704856625",
#     "Brokered Name": "Realco Brokers, Inc.",
#     "Estimated Price": "$11,977 ",
#     "Property Type": "Single family",
#     "Days on Market": "67 days",
#     "Year Built": "2025",
#     "Zip Code": "30318",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/727-Berkeley-Ave-NW_Atlanta_GA_30318_M54243-20145"
#   },
#   {
#     "Price": "$1,080,000",
#     "Address": "156 Martha Ave NE, Atlanta, GA 30317",
#     "Realtor's Name": "Nikkia Holmes",
#     "Realtor's Email": "nikkia@newvisionsrealestatefirm.net",
#     "Realtor's Phone": "4044613219",
#     "Brokered Name": "New Visions Real Estate Firm, Llc",
#     "Estimated Price": "$6,539 ",
#     "Property Type": "Single family",
#     "Days on Market": "16 days",
#     "Year Built": "2024",
#     "Zip Code": "30317",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/156-Martha-Ave-NE_Atlanta_GA_30317_M69695-09408"
#   },
#   {
#     "Price": "$800,000",
#     "Address": "337 Pine St NE Unit B, Atlanta, GA 30308",
#     "Realtor's Name": "Adriana Herrera",
#     "Realtor's Email": "adriana.herrera@cbrealty.com",
#     "Realtor's Phone": "4048742262",
#     "Brokered Name": "METHOD REAL ESTATE ADVISORS",
#     "Estimated Price": "$5,061 ",
#     "Property Type": "Townhomes",
#     "Days on Market": "96 days",
#     "Year Built": "2024",
#     "Zip Code": "30308",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/337-Pine-St-NE-B_Atlanta_GA_30308_M94450-29210"
#   },
#   {
#     "Price": "$1,064,000",
#     "Address": "10 Moreland Ave NE, Atlanta, GA 30307",
#     "Realtor's Name": "Richard Derossett",
#     "Realtor's Email": "richard.derossett@coldwellbankeratlanta.com",
#     "Realtor's Phone": "4042524908",
#     "Brokered Name": "Coldwell Banker Realty",
#     "Estimated Price": "$6,200 ",
#     "Property Type": "Single family",
#     "Days on Market": "179 days",
#     "Year Built": "2024",
#     "Zip Code": "30307",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/10-Moreland-Ave-NE_Atlanta_GA_30307_M64999-24934"
#   },
#   {
#     "Price": "$2,450,000",
#     "Address": "585 Sherwood Rd NE, Atlanta, GA 30324",
#     "Realtor's Name": "ELENA GIST",
#     "Realtor's Email": "ELENAGIST@YAHOO.COM",
#     "Realtor's Phone": "4042720812",
#     "Brokered Name": "KELLER WILLIAMS REALTY BUCKHEAD",
#     "Estimated Price": "$14,608 ",
#     "Property Type": "Single family",
#     "Days on Market": "18 days",
#     "Year Built": "2025",
#     "Zip Code": "30324",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/585-Sherwood-Rd-NE_Atlanta_GA_30324_M61760-39291"
#   },
#   {
#     "Price": "$1,995,000",
#     "Address": "2425 Peachtree Rd NE Unit 701, Atlanta, GA 30305",
#     "Realtor's Name": "Erin Connolly",
#     "Realtor's Email": "erinkconnolly@gmail.com",
#     "Realtor's Phone": "4043689775",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$14,549 ",
#     "Property Type": "Condo",
#     "Days on Market": "83 days",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2425-Peachtree-Rd-NE-701_Atlanta_GA_30305_M97937-42272"
#   },
#   {
#     "Price": "$1,745,000",
#     "Address": "2571 Sharondale Dr NE, Atlanta, GA 30305",
#     "Realtor's Name": "Bonneau Ansley",
#     "Realtor's Email": "bonneau@ansleyatlanta.com",
#     "Realtor's Phone": "4049063161",
#     "Brokered Name": "Ansley Real Estate",
#     "Estimated Price": "$11,400 ",
#     "Property Type": "Single family",
#     "Days on Market": "90 days",
#     "Year Built": "2023",
#     "Zip Code": "30305",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2571-Sharondale-Dr-NE_Atlanta_GA_30305_M54044-03685"
#   },
#   {
#     "Price": "$1,850,000",
#     "Address": "2369 Drew Valley Rd NE, Atlanta, GA 30319",
#     "Realtor's Name": "Mike Toltzis",
#     "Realtor's Email": "mike.toltzis@coldwellbankeratlanta.com",
#     "Realtor's Phone": "4043769135",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$10,786 ",
#     "Property Type": "Single family",
#     "Days on Market": "54 days",
#     "Year Built": "2025",
#     "Zip Code": "30319",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2369-Drew-Valley-Rd-NE_Brookhaven_GA_30319_M67272-01175"
#   },
#   {
#     "Price": "$995,000",
#     "Address": "625 Home Ave SE, Atlanta, GA 30312",
#     "Realtor's Name": "Jessica Colclough",
#     "Realtor's Email": "JCOLCLOUGH@BELLSOUTH.NET",
#     "Realtor's Phone": "4044019914",
#     "Brokered Name": "Bolst, Inc.",
#     "Estimated Price": "$6,146 ",
#     "Property Type": "Single family",
#     "Days on Market": "116 days",
#     "Year Built": "2023",
#     "Zip Code": "30312",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/625-Home-Ave-SE_Atlanta_GA_30312_M90233-91955"
#   },
#   {
#     "Price": "$3,199,000",
#     "Address": "1366 Wessyngton Rd NE, Atlanta, GA 30306",
#     "Realtor's Name": "Saige Simone Haynes",
#     "Realtor's Email": "saige.haynes@gmail.com",
#     "Realtor's Phone": "4049075444",
#     "Brokered Name": "S&S Luxury Realty Group, LLC",
#     "Estimated Price": "$18,525 ",
#     "Property Type": "Single family",
#     "Days on Market": "43 days",
#     "Year Built": "2025",
#     "Zip Code": "30306",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1366-Wessyngton-Rd-NE_Atlanta_GA_30306_M91086-54329"
#   },
#   {
#     "Price": "$3,850,000",
#     "Address": "2425 Peachtree Rd NE Unit 1705, Atlanta, GA 30305",
#     "Realtor's Name": "Sam Bayne",
#     "Realtor's Email": "sam@atlantafinehomes.com",
#     "Realtor's Phone": "4042375000",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$27,433 ",
#     "Property Type": "Condo",
#     "Days on Market": "26 days",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2425-Peachtree-Rd-NE-Unit-1705_Atlanta_GA_30305_M92274-51513"
#   },
#   {
#     "Price": "$2,500,000",
#     "Address": "3534 Rockhaven Cir NE, Atlanta, GA 30324",
#     "Realtor's Name": "Quentiss Servick",
#     "Realtor's Email": "quentiss@integrityrealestatega.com",
#     "Realtor's Phone": "7706955909",
#     "Brokered Name": "Integrity Real Estate Georgia",
#     "Estimated Price": "$14,210 ",
#     "Property Type": "Single family",
#     "Days on Market": "27 days",
#     "Year Built": "2025",
#     "Zip Code": "30324",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3534-Rockhaven-Cir-NE_Atlanta_GA_30324_M58308-75834"
#   },
#   {
#     "Price": "$1,950,000",
#     "Address": "4412 Brookview Dr SE, Atlanta, GA 30339",
#     "Realtor's Name": "Susan M Protos",
#     "Realtor's Email": "sprotos.homesmart@gmail.com",
#     "Realtor's Phone": "4047711791",
#     "Brokered Name": "HomeSmart",
#     "Estimated Price": "$11,401 ",
#     "Property Type": "Single family",
#     "Days on Market": "87 days",
#     "Year Built": "2025",
#     "Zip Code": "30339",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4412-Brookview-Dr-SE_Atlanta_GA_30339_M99654-30219"
#   },
#   {
#     "Price": "$1,660,000",
#     "Address": "2425 Peachtree Rd NE Unit 510, Atlanta, GA 30305",
#     "Realtor's Name": "Nicholas Daniel Brown",
#     "Realtor's Email": "nicholas.brown@compass.com",
#     "Realtor's Phone": "7706305430",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$11,886 ",
#     "Property Type": "Condo",
#     "Days on Market": "119 days",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2425-Peachtree-Rd-NE-Unit-510_Atlanta_GA_30305_M94048-83491"
#   },
#   {
#     "Price": "$975,000",
#     "Address": "1103 Boulevard Dr SE, Atlanta, GA 30317",
#     "Realtor's Name": "Steve Raimonde",
#     "Realtor's Email": "steve@kellerknapp.com",
#     "Realtor's Phone": "4044341500",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$5,707 ",
#     "Property Type": "Townhomes",
#     "Days on Market": "33 days",
#     "Year Built": "2025",
#     "Zip Code": "30317",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1103-Boulevard-Dr-SE_Atlanta_GA_30317_M94166-24198"
#   },
#   {
#     "Price": "$2,399,000",
#     "Address": "2425 Peachtree Rd NE Unit 505, Atlanta, GA 30305",
#     "Realtor's Name": "Kevin Mcbride",
#     "Realtor's Email": "kevinmcbride@atlantafinehomes.com",
#     "Realtor's Phone": "4048740300",
#     "Brokered Name": "Atlanta Fine Homes Sotheby's International Realty",
#     "Estimated Price": "$17,487 ",
#     "Property Type": "Condo",
#     "Days on Market": "27 days",
#     "Year Built": "2024",
#     "Zip Code": "30305",
#     "Multi Listings": 2,
# ...
#     "Property Type": "Multi-Family",
#     "Days on Market": "64 days",
#     "Year Built": "2024",
#     "Zip Code": "30318",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1186-Francis-St-NW_Atlanta_GA_30318_M53982-26465"
#   },
#   {
#     "Price": "$819,900",
#     "Address": "816 Berne St SE Apt 4, Atlanta, GA 30316",
#     "Realtor's Name": "Allyson Golightly",
#     "Realtor's Email": "golightlyally@gmail.com",
#     "Realtor's Phone": "4042345989",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$5,761 ",
#     "Property Type": "Townhomes",
#     "Days on Market": "44 days",
#     "Year Built": "2025",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/816-Berne-St-SE-Apt-4_Atlanta_GA_30316_M95217-69651"
#   },
#   {
#     "Price": "$979,900",
#     "Address": "1434 Fairmont Ave NW, Atlanta, GA 30318",
#     "Realtor's Name": "Ursula Parker",
#     "Realtor's Email": "ursula.parker@cbrealty.com",
#     "Realtor's Phone": "7704290600",
#     "Brokered Name": "New Home Star Georgia, LLC",
#     "Estimated Price": "$5,693 ",
#     "Property Type": "Single family",
#     "Days on Market": "301 days",
#     "Year Built": "2024",
#     "Zip Code": "30318",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1434-Fairmont-Ave-NW_Atlanta_GA_30318_M92022-61446"
#   },
#   {
#     "Price": "$999,000",
#     "Address": "88 Cleveland St SE Unit B, Atlanta, GA 30316",
#     "Realtor's Name": "Barbara Spiller",
#     "Realtor's Email": "bobbie@eketsa.com",
#     "Realtor's Phone": "4047485988",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$5,762 ",
#     "Property Type": "Single family",
#     "Days on Market": "99 days",
#     "Year Built": "2024",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/88-Cleveland-St-SE-B_Atlanta_GA_30316_M98952-83911"
#   },
#   {
#     "Price": "$999,999",
#     "Address": "1273 Danner St SE, Atlanta, GA 30316",
#     "Realtor's Name": "Tristain O'Donnell",
#     "Realtor's Email": "tristain.odonnell@engelvoelkers.com",
#     "Realtor's Phone": "6786832849",
#     "Brokered Name": "Engel & Volkers Atlanta",
#     "Estimated Price": "$5,893 ",
#     "Property Type": "Single family",
#     "Days on Market": "53 days",
#     "Year Built": "2025",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1273-Danner-St-SE_Atlanta_GA_30316_M53585-53980"
#   },
#   {
#     "Price": "$2,450,000",
#     "Address": "245 River Valley Ct Lot 3, Atlanta, GA 30328",
#     "Realtor's Name": "Nicholas Daniel Brown",
#     "Realtor's Email": "nicholas.brown@compass.com",
#     "Realtor's Phone": "7706305430",
#     "Brokered Name": "COMPASS",
#     "Estimated Price": "$16,410 ",
#     "Property Type": "Single family",
#     "Days on Market": "81 days",
#     "Year Built": "2025",
#     "Zip Code": "30328",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/245-River-Valley-Ct-3_Sandy-Springs_GA_30328_M90772-03175"
#   },
#   {
#     "Price": "$1,050,000",
#     "Address": "1610 Niskey Lake Rd SW, Atlanta, GA 30331",
#     "Realtor's Name": "Will Melton",
#     "Realtor's Email": "wmelton@kw.com",
#     "Realtor's Phone": "7706564104",
#     "Brokered Name": "Keller Williams Realty Metro Atlanta",
#     "Estimated Price": "$5,827 ",
#     "Property Type": "Single family",
#     "Days on Market": "14 days",
#     "Year Built": "2024",
#     "Zip Code": "30331",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1610-Niskey-Lake-Rd-SW_Atlanta_GA_30331_M98221-01966"
#   },
#   {
#     "Price": "$999,000",
#     "Address": "90 Cleveland St SE Unit B, Atlanta, GA 30316",
#     "Realtor's Name": "Barbara Spiller",
#     "Realtor's Email": "bobbie@eketsa.com",
#     "Realtor's Phone": "4047485988",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$5,607 ",
#     "Property Type": "Single family",
#     "Days on Market": "99 days",
#     "Year Built": "2024",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/90-Cleveland-St-SE-B_Atlanta_GA_30316_M94715-85328"
#   },
#   {
#     "Price": "$950,000",
#     "Address": "1081 Napier St SE, Atlanta, GA 30316",
#     "Realtor's Name": "Elijah Tutt",
#     "Realtor's Email": "",
#     "Realtor's Phone": "4048005338",
#     "Brokered Name": "KELLER WILLIAMS REALTY BUCKHEAD",
#     "Estimated Price": "$5,453 ",
#     "Property Type": "Single family",
#     "Days on Market": "22 days",
#     "Year Built": "2025",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1081-Napier-St-SE_Atlanta_GA_30316_M65276-01117"
#   },
#   {
#     "Price": "$875,000",
#     "Address": "5185 Cascade Rd SW, Atlanta, GA 30331",
#     "Realtor's Name": "Jerri Grier-caldwell",
#     "Realtor's Email": "",
#     "Realtor's Phone": "N/A",
#     "Brokered Name": "N/A",
#     "Estimated Price": "$4,955 ",
#     "Property Type": "Single family",
#     "Days on Market": "27 days",
#     "Year Built": "2025",
#     "Zip Code": "N/A",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/5185-Cascade-Rd-SW_Atlanta_GA_30331_M55095-25987",
#     "error": "'NoneType' object is not subscriptable"
#   },
#   {
#     "Price": "$950,000",
#     "Address": "4821 Neal Rdg, Atlanta, GA 30349",
#     "Realtor's Name": "Eric Walton",
#     "Realtor's Email": "ericwalton@atlantafinehomes.com",
#     "Realtor's Phone": "6786518135",
#     "Brokered Name": "Pristine Palaces Realty, LLC",
#     "Estimated Price": "$5,434 ",
#     "Property Type": "Single family",
#     "Days on Market": "319 days",
#     "Year Built": "2024",
#     "Zip Code": "30349",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4821-Neal-Rdg_Atlanta_GA_30349_M93956-23728"
#   },
#   {
#     "Price": "$848,621",
#     "Address": "1115 Rivard Cir NW, Atlanta, GA 30318",
#     "Realtor's Name": "Altus at The Quarter",
#     "Realtor's Email": null,
#     "Realtor's Phone": "N/A",
#     "Brokered Name": "N/A",
#     "Estimated Price": "$5,678 ",
#     "Property Type": "Townhomes",
#     "Days on Market": null,
#     "Year Built": null,
#     "Zip Code": "N/A",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1115-Rivard-Cir-NW_Atlanta_GA_30318_M90766-77997",
#     "error": "'NoneType' object is not subscriptable"
#   },
#   {
#     "Price": "$999,000",
#     "Address": "90 Cleveland St SE Unit A, Atlanta, GA 30316",
#     "Realtor's Name": "Barbara Spiller",
#     "Realtor's Email": "bobbie@eketsa.com",
#     "Realtor's Phone": "4047485988",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$5,607 ",
#     "Property Type": "Single family",
#     "Days on Market": "99 days",
#     "Year Built": "2024",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/90-Cleveland-St-SE-A_Atlanta_GA_30316_M94723-11215"
#   },
#   {
#     "Price": "$874,264",
#     "Address": "1105 Rivard Cir NW, Atlanta, GA 30318",
#     "Realtor's Name": "Altus at The Quarter",
#     "Realtor's Email": null,
#     "Realtor's Phone": "N/A",
#     "Brokered Name": "N/A",
#     "Estimated Price": "$5,850 ",
#     "Property Type": "Townhomes",
#     "Days on Market": null,
#     "Year Built": null,
#     "Zip Code": "N/A",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1105-Rivard-Cir-NW_Atlanta_GA_30318_M98429-37485",
#     "error": "'NoneType' object is not subscriptable"
#   },
#   {
#     "Price": "$800,000",
#     "Address": "1173 Veltre Cir SW, Atlanta, GA 30311",
#     "Realtor's Name": "Clarissa Gilmore",
#     "Realtor's Email": "gilmoregirlrealty@gmail.com",
#     "Realtor's Phone": "4048764901",
#     "Brokered Name": "Norluxe Realty Midtown LLC",
#     "Estimated Price": "$4,512 ",
#     "Property Type": "Single family",
#     "Days on Market": "74 days",
#     "Year Built": "2025",
#     "Zip Code": "30311",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1173-Veltre-Cir-SW_Atlanta_GA_30311_M99529-23389"
#   },
#   {
#     "Price": "$934,900",
#     "Address": "3967 Tilly Mill Rd, Atlanta, GA 30360",
#     "Realtor's Name": "Connie Brackbill",
#     "Realtor's Email": "connie@clmhomes.net",
#     "Realtor's Phone": "6789102403",
#     "Brokered Name": "Chapman Hall Realtors",
#     "Estimated Price": "$5,289 ",
#     "Property Type": "Single family",
#     "Days on Market": "415 days",
#     "Year Built": "2024",
#     "Zip Code": "30360",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3967-Tilly-Mill-Rd_Atlanta_GA_30360_M61923-00358"
#   },
#   {
#     "Price": "$1,179,000",
#     "Address": "1063 Ormewood Ave SE, Atlanta, GA 30316",
#     "Realtor's Name": "STEVEN CARPENTER",
#     "Realtor's Email": "scratl1@gmail.com",
#     "Realtor's Phone": "(404) 402-3143",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$7,225 ",
#     "Property Type": "Single family",
#     "Days on Market": "95 days",
#     "Year Built": "2024",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1063-Ormewood-Ave-SE_Atlanta_GA_30316_M53228-55133"
#   },
#   {
#     "Price": "$849,900",
#     "Address": "1439 Van Vleck Ave SE, Atlanta, GA 30316",
#     "Realtor's Name": "Gabriel Young",
#     "Realtor's Email": "",
#     "Realtor's Phone": "(678) 521-8987",
#     "Brokered Name": "Kasper Realty Professionals, Llc",
#     "Estimated Price": "$4,826 ",
#     "Property Type": "Single family",
#     "Days on Market": "21 days",
#     "Year Built": "2024",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1439-Van-Vleck-Ave-SE_Atlanta_GA_30316_M64785-04722"
#   },
#   {
#     "Price": "$1,290,000",
#     "Address": "2190 William Way, Atlanta, GA 30345",
#     "Realtor's Name": "CANDACE FUQUA",
#     "Realtor's Email": "cdfuqua@mindspring.com",
#     "Realtor's Phone": "7709129003",
#     "Brokered Name": "Avenue Realty East Decatur Sta",
#     "Estimated Price": "$7,462 ",
#     "Property Type": "Single family",
#     "Days on Market": "533 days",
#     "Year Built": "2024",
#     "Zip Code": "30345",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2190-William-Way_Atlanta_GA_30345_M99203-17912"
#   },
#   {
#     "Price": "$950,000",
#     "Address": "4837 Neal Rdg, Atlanta, GA 30349",
#     "Realtor's Name": "Eric Walton",
#     "Realtor's Email": "ericwalton@atlantafinehomes.com",
#     "Realtor's Phone": "6786518135",
#     "Brokered Name": "Pristine Palaces Realty, LLC",
#     "Estimated Price": "$5,445 ",
#     "Property Type": "Single family",
#     "Days on Market": "319 days",
#     "Year Built": "2024",
#     "Zip Code": "30349",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4837-Neal-Rdg_Atlanta_GA_30349_M96041-52125"
#   },
#   {
#     "Price": "$950,000",
#     "Address": "4825 Neal Rdg, Atlanta, GA 30349",
#     "Realtor's Name": "Eric Walton",
#     "Realtor's Email": "ericwalton@atlantafinehomes.com",
#     "Realtor's Phone": "6786518135",
#     "Brokered Name": "Pristine Palaces Realty, LLC",
#     "Estimated Price": "$5,436 ",
#     "Property Type": "Single family",
#     "Days on Market": "319 days",
#     "Year Built": "2024",
#     "Zip Code": "30349",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4825-Neal-Rdg_Atlanta_GA_30349_M97733-59859"
#   },
#   {
#     "Price": "$995,000",
#     "Address": "1967 Nash Ave SE, Atlanta, GA 30316",
#     "Realtor's Name": "Chad Polazzo",
#     "Realtor's Email": "chadpolazzo@remax.net",
#     "Realtor's Phone": "4042267199",
#     "Brokered Name": "RE MAX Metro Atlanta Cityside",
#     "Estimated Price": "$5,550 ",
#     "Property Type": "Single family",
#     "Days on Market": "14 days",
#     "Year Built": "2025",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1967-Nash-Ave-SE_Atlanta_GA_30316_M50363-36957"
#   },
#   {
#     "Price": "$900,000",
#     "Address": "2840 Tee Rd SW, Atlanta, GA 30311",
#     "Realtor's Name": "Tameika Jordan",
#     "Realtor's Email": "transitionrealty@comcast.net",
#     "Realtor's Phone": "(678) 538-0401",
#     "Brokered Name": "Transition Realty, Inc.",
#     "Estimated Price": "$5,064 ",
#     "Property Type": "Single family",
#     "Days on Market": "342 days",
#     "Year Built": "2024",
#     "Zip Code": "30311",
#     "Multi Listings": "N/A",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2840-Tee-Rd-SW_Atlanta_GA_30311_M59050-11886"
#   },
#   {
#     "Price": "$999,900",
#     "Address": "214 Estoria St SE, Atlanta, GA 30316",
#     "Realtor's Name": "Weslee Knapp",
#     "Realtor's Email": "weslee@kellerknapp.com",
#     "Realtor's Phone": "6783584321",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$5,773 ",
#     "Property Type": "Single family",
#     "Days on Market": "83 days",
#     "Year Built": "2024",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/214-Estoria-St-SE_Atlanta_GA_30316_M95325-62090"
#   },
#   {
#     "Price": "$1,250,000",
#     "Address": "2519 Cherry Hill Ln, Atlanta, GA 30360",
#     "Realtor's Name": "Connie Brackbill",
#     "Realtor's Email": "connie@clmhomes.net",
#     "Realtor's Phone": "6789102403",
#     "Brokered Name": "Chapman Hall Realtors",
#     "Estimated Price": "$7,042 ",
#     "Property Type": "Single family",
#     "Days on Market": "40 days",
#     "Year Built": "2025",
#     "Zip Code": "30360",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2519-Cherry-Hill-Ln_Atlanta_GA_30360_M51832-76326"
#   },
#   {
#     "Price": "$850,000",
#     "Address": "140 N Woodland Dr, Atlanta, GA 30340",
#     "Realtor's Name": "Jeannette Munarriz",
#     "Realtor's Email": "jmunarrizrealtor@gmail.com",
#     "Realtor's Phone": "4043227871",
#     "Brokered Name": "La Rosa Realty Georgia",
#     "Estimated Price": "$4,725 ",
#     "Property Type": "Single family",
#     "Days on Market": "19 days",
#     "Year Built": "2025",
#     "Zip Code": "30340",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/140-N-Woodland-Dr_Atlanta_GA_30340_M58706-10927"
#   },
#   {
#     "Price": "$1,125,000",
#     "Address": "4217 Danforth Rd SW, Atlanta, GA 30331",
#     "Realtor's Name": "Gabrielle Johnson",
#     "Realtor's Email": "gabrielle.johnson@bhhsgeorgia.com",
#     "Realtor's Phone": "6786156441",
#     "Brokered Name": "The Armani Agency, LLC",
#     "Estimated Price": "$6,804 ",
#     "Property Type": "Single family",
#     "Days on Market": "98 days",
#     "Year Built": "2024",
#     "Zip Code": "30331",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4217-Danforth-Rd-SW_Atlanta_GA_30331_M59069-00803"
#   },
#   {
#     "Price": "$1,225,000",
#     "Address": "1102 Morley Ave SE, Atlanta, GA 30312",
#     "Realtor's Name": "Barbara Spiller",
#     "Realtor's Email": "bobbie@eketsa.com",
#     "Realtor's Phone": "4047485988",
#     "Brokered Name": "KELLER KNAPP INC",
#     "Estimated Price": "$6,997 ",
#     "Property Type": "Single family",
#     "Days on Market": "7 hours",
#     "Year Built": "2024",
#     "Zip Code": "30312",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1102-Morley-Ave-SE_Atlanta_GA_30312_M52468-07940"
#   },
#   {
#     "Price": "$856,452",
#     "Address": "127 Stein Steel St Unit 12, Atlanta, GA 30316",
#     "Realtor's Name": "Gail Olson",
#     "Realtor's Email": "gailolson@atlantafinehomes.com",
#     "Realtor's Phone": "4047833099",
#     "Brokered Name": "Ea Brokerage Llc",
#     "Estimated Price": "$5,822 ",
#     "Property Type": "Condo",
#     "Days on Market": "99 days",
#     "Year Built": "2024",
#     "Zip Code": "30316",
#     "Multi Listings": 2,
#     "Link": "https://www.realtor.com/realestateandhomes-detail/127-Stein-Steel-St-Unit-12_Atlanta_GA_30316_M99452-81805"
#   }
# ]
